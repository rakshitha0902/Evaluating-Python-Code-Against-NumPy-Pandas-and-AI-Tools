# %%
#Rakshitha Ramachandra [K00302101] Mahesh Vootla [k00302085]
# Task 1 
import csv
import time

# Function to load data from a CSV file
def load_data(file_path):
    """Loads data from a CSV file into a list of rows."""
    data = []
    with open(file_path, 'r') as file:
        reader = csv.reader(file) # Read the file as a CSV
        headers = next(reader) # Save the first row as headers (column names)
        for row in reader: # Read the rest of the rows
            data.append(row)
    return headers, data # Return both headers and the rest of the data

# Function to calculate summary statistics for numerical and categorical columns
def calculate_summary_statistics(data, headers, num_columns, cat_columns):
    """Calculates summary statistics for numerical columns and frequency counts for categorical columns."""
    # Find the positions (indexes) of the columns in the dataset
    num_col_indices = [headers.index(col) for col in num_columns]
    cat_col_indices = [headers.index(col) for col in cat_columns]

    # Prepare dictionaries to store results
    # Numerical columns: mean, min, max, std, percentiles
    numerical_stats = {col: {'values': []} for col in num_columns}
    # Categorical columns: frequency counts, mode, proportions, unique count
    categorical_stats = {col: {'counts': {}, 'mode': None, 'unique_count': 0, 'proportions': {}} for col in cat_columns}

    # Go through each row of data
    for row in data:
        # Process numerical columns
        for col, idx in zip(num_columns, num_col_indices):
            try:
                value = float(row[idx]) # Convert the value to a number
                numerical_stats[col]['values'].append(value) # Store the value for later calculations
            except ValueError:
                continue # Skip if value is not a valid number

        # Process categorical columns
        for col, idx in zip(cat_columns, cat_col_indices):
            value = row[idx] # Get the value in the column
            if value in categorical_stats[col]['counts']:
                categorical_stats[col]['counts'][value] += 1 # Increment the count for this value
            else:
                categorical_stats[col]['counts'][value] = 1 # Add the value to the dictionary with count 1

    # Calculate statistics for numerical columns
    for col, stats in numerical_stats.items():
        values = stats['values'] # Get the list of all values
        if values: # Only calculate if there are valid values
            stats['mean'] = sum(values) / len(values) # Calculate mean
            stats['min'] = min(values) # Find minimum
            stats['max'] = max(values) # Find maximum
            stats['std'] = (sum((x - stats['mean']) ** 2 for x in values) / len(values)) ** 0.5 # Standard deviation
            sorted_values = sorted(values) # Sort values for percentiles
            stats['25%'] = sorted_values[int(0.25 * len(sorted_values))] # 25th percentile
            stats['50%'] = sorted_values[int(0.5 * len(sorted_values))] # 50th percentile (median)
            stats['75%'] = sorted_values[int(0.75 * len(sorted_values))] # 75th percentile
        else:
            stats.update({'mean': None, 'min': None, 'max': None, 'std': None, '25%': None, '50%': None, '75%': None})

    # Calculate statistics for categorical columns
    for col, stats in categorical_stats.items():
        counts = stats['counts']
        total = sum(counts.values()) # Total occurrences
        if total > 0:
            stats['mode'] = max(counts, key=counts.get) # Most frequent category
            stats['unique_count'] = len(counts) # Number of unique categories
            stats['proportions'] = {key: value / total for key, value in counts.items()} # Proportions of each category

    return numerical_stats, categorical_stats # Return both numerical and categorical stats

# Main task: Load data, calculate statistics, and measure runtime
file_path = 'C:/Users/raksh/OneDrive/Documents/NSE_BANKING_SECTOR.csv' # File location
headers, stock_data = load_data(file_path) # Load data from the file

# Specify numerical and categorical columns
num_columns_stock = ["PREV CLOSE", "OPEN", "HIGH", "LOW", "LAST", "CLOSE", "VWAP", "VOLUME", "TURNOVER", "TRADES", "DELIVERABLE VOLUME", "%DELIVERBLE"]
cat_columns_stock = ["SYMBOL"]

# Measure how long it takes to calculate the statistics
start_time = time.time() # Start the timer
numerical_stats, categorical_stats = calculate_summary_statistics(stock_data, headers, num_columns_stock, cat_columns_stock)
task_1_time = time.time() - start_time # Calculate the total time taken

# Display the results for numerical statistics
print("Task 1: Stock Data Summary Statistics (Using Basic Python):")
print("===" * 10)
for col, stats in numerical_stats.items():
    print(f"{col}:")
    print(f" Mean = {stats['mean']}, Min = {stats['min']}, Max = {stats['max']}, Std = {stats['std']}")
    print(f" 25% = {stats['25%']}, 50% (Median) = {stats['50%']}, 75% = {stats['75%']}")
    print("---" * 10)

# Display the results for categorical statistics
print("\nCategorical Summary Statistics:")
for col, stats in categorical_stats.items():
    print(f"{col}:")
    print(f" Mode = {stats['mode']}")
    print(f" Unique Count = {stats['unique_count']}")
    print(f" Proportions:")
    for category, proportion in stats['proportions'].items():
        print(f" {category}: {proportion:.2%}")
    print(f" Frequency Counts:")
    for category, count in stats['counts'].items():
        print(f" {category}: {count}")
        print("---" * 10)

# Display the runtime
print(f"\nTask 1 Runtime: {task_1_time} seconds\n")
# Out:
# Task 1: Stock Data Summary Statistics (Using Basic Python):
# ==============================
# PREV CLOSE:
#  Mean = 291.9627525405641, Min = 4.9, Max = 2860.45, Std = 452.5355398186211
#  25% = 37.15, 50% (Median) = 101.9, 75% = 305.7
# ------------------------------
# OPEN:
#  Mean = 292.35094710290804, Min = 4.95, Max = 2871.0, Std = 452.96239909773357
#  25% = 37.3, 50% (Median) = 102.0, 75% = 306.15
# ------------------------------
# HIGH:
#  Mean = 296.51848366520335, Min = 4.95, Max = 2896.0, Std = 458.2192000361757
#  25% = 37.95, 50% (Median) = 103.8, 75% = 311.4
# ------------------------------
# LOW:
#  Mean = 287.72344837622177, Min = 4.8, Max = 2838.0, Std = 447.0640102126365
#  25% = 36.45, 50% (Median) = 99.8, 75% = 301.05
# ------------------------------
# LAST:
#  Mean = 291.99360553952124, Min = 4.9, Max = 2861.55, Std = 452.7118531255126
#  25% = 37.1, 50% (Median) = 101.75, 75% = 305.8
# ------------------------------
# CLOSE:
#  Mean = 292.01308845286314, Min = 4.9, Max = 2860.45, Std = 452.7265739893205
#  25% = 37.1, 50% (Median) = 101.85, 75% = 305.7
# ------------------------------
# VWAP:
#  Mean = 292.1607307608353, Min = 4.91, Max = 2867.92, Std = 452.64982441607486
#  25% = 37.23, 50% (Median) = 102.02, 75% = 306.36
# ------------------------------
# VOLUME:
#  Mean = 10426502.07695666, Min = 9194.0, Max = 1264917719.0, Std = 29539362.983443994
#  25% = 821677.0, 50% (Median) = 2777826.0, 75% = 9769893.0
# ------------------------------
# TURNOVER:
#  Mean = 195361514527105.94, Min = 16816279999.999996, Max = 1.4982219064275e+16, Std = 403862603307442.25
#  25% = 5730247690000.0, 50% (Median) = 40259611740000.0, 75% = 204183363675000.0
# ------------------------------
# TRADES:
#  Mean = 52218.115786665374, Min = 94.0, Max = 1788274.0, Std = 88509.1339876282
#  25% = 5397.0, 50% (Median) = 19280.0, 75% = 62975.0
# ------------------------------
# DELIVERABLE VOLUME:
#  Mean = 3026934.880963353, Min = 7392.0, Max = 787086390.0, Std = 9387414.258769438
#  25% = 345722.0, 50% (Median) = 958438.0, 75% = 2929394.0
# ------------------------------
# %DELIVERBLE:
#  Mean = 0.41541646819140937, Min = 0.0201, Max = 1.0, Std = 0.19611985495768788
#  25% = 0.2527, 50% (Median) = 0.4147, 75% = 0.5632
# ------------------------------
#
# Categorical Summary Statistics:
# SYMBOL:
#  Mode = HDFC
#  Unique Count = 36
#  Proportions:
#  HDFC: 3.24%
#  ICICIBANK: 3.24%
#  SBIN: 3.24%
#  KOTAKBANK: 3.24%
#  AXISBANK: 3.24%
#  INDUSINDBK: 3.24%
#  BANDHANBNK: 1.90%
#  PNB: 3.24%
#  BANKBARODA: 3.24%
#  IDBI: 3.24%
#  IDFCBANK: 1.82%
#  IDFCFIRSTB: 1.42%
#  YESBANK: 3.24%
#  AUBANK: 2.33%
#  IOB: 3.24%
#  CANBK: 3.24%
#  BANKINDIA: 3.24%
#  UNIONBANK: 3.24%
#  FEDERALBNK: 3.24%
#  MAHABANK: 3.24%
#  INDIANB: 3.24%
#  UCOBANK: 3.24%
#  CUB: 3.24%
#  RBLBANK: 2.84%
#  CENTRALBK: 3.24%
#  PSB: 3.24%
#  EQUITASBNK: 0.34%
#  CSBBANK: 0.90%
#  UJJIVANSFB: 0.88%
#  KARURVYSYA: 3.24%
#  DCBBANK: 3.24%
#  SURYODAY: 0.10%
#  SOUTHBANK: 3.24%
#  J&KBANK: 3.24%
#  KTKBANK: 3.24%
#  DHANBANK: 3.15%
#  Frequency Counts:
#  HDFC: 1337
# ------------------------------
#  ICICIBANK: 1337
# ------------------------------
#  SBIN: 1337
# ------------------------------
#  KOTAKBANK: 1337
# ------------------------------
#  AXISBANK: 1337
# ------------------------------
#  INDUSINDBK: 1337
# ------------------------------
#  BANDHANBNK: 784
# ------------------------------
#  PNB: 1337
# ------------------------------
#  BANKBARODA: 1337
# ------------------------------
#  IDBI: 1337
# ------------------------------
#  IDFCBANK: 752
# ------------------------------
#  IDFCFIRSTB: 585
# ------------------------------
#  YESBANK: 1337
# ------------------------------
#  AUBANK: 962
# ------------------------------
#  IOB: 1337
# ------------------------------
#  CANBK: 1337
# ------------------------------
#  BANKINDIA: 1337
# ------------------------------
#  UNIONBANK: 1337
# ------------------------------
#  FEDERALBNK: 1337
# ------------------------------
#  MAHABANK: 1337
# ------------------------------
#  INDIANB: 1337
# ------------------------------
#  UCOBANK: 1337
# ------------------------------
#  CUB: 1337
# ------------------------------
#  RBLBANK: 1173
# ------------------------------
#  CENTRALBK: 1337
# ------------------------------
#  PSB: 1337
# ------------------------------
#  EQUITASBNK: 141
# ------------------------------
#  CSBBANK: 370
# ------------------------------
#  UJJIVANSFB: 364
# ------------------------------
#  KARURVYSYA: 1337
# ------------------------------
#  DCBBANK: 1337
# ------------------------------
#  SURYODAY: 41
# ------------------------------
#  SOUTHBANK: 1337
# ------------------------------
#  J&KBANK: 1337
# ------------------------------
#  KTKBANK: 1337
# ------------------------------
#  DHANBANK: 1297
# ------------------------------
#
# Task 1 Runtime: 0.5330910682678223 seconds

# %%
#Task 2 with original file
import pandas as pd
import time

def calculate_with_pandas(file_path, num_columns, cat_columns):
    """Calculates summary statistics using Pandas for efficiency comparison."""
    start_time = time.time()
    data = pd.read_csv(file_path)

    # Calculate summary statistics for numerical columns
    numerical_summary = data[num_columns].describe()

    # Calculate frequency counts, mode, unique count, and proportions for categorical columns
    categorical_stats = {}
    for col in cat_columns:
        value_counts = data[col].value_counts() # Frequency counts
        total = len(data[col]) # Total rows
        categorical_stats[col] = {
            "mode": value_counts.idxmax(), # Mode (most frequent value)
            "unique_count": value_counts.size, # Count of unique categories
            "proportions": (value_counts / total).to_dict(), # Proportions for each category
            "counts": value_counts.to_dict() # Frequency counts as a dictionary
        }

    task_2_time = time.time() - start_time

    return numerical_summary, categorical_stats, task_2_time

# Task 2 Execution
file_path = 'C:/Users/raksh/OneDrive/Documents/NSE_BANKING_SECTOR.csv' #original file
num_columns_stock = ["PREV CLOSE", "OPEN", "HIGH", "LOW", "LAST", "CLOSE", "VWAP", "VOLUME", "TURNOVER", "TRADES", "DELIVERABLE VOLUME", "%DELIVERBLE"]
cat_columns_stock = ["SYMBOL"]

numerical_summary_pandas, categorical_stats_pandas, task_2_time = calculate_with_pandas(file_path, num_columns_stock, cat_columns_stock)

# Display results for Task 2
print("Task 2: Summary Statistics with Pandas (for Efficiency Comparison):")
print(numerical_summary_pandas)

print("\nCategorical Summary Statistics:")
for col, stats in categorical_stats_pandas.items():
    print(f"{col}:")
    print(f" Mode: {stats['mode']}")
    print(f" Unique Count: {stats['unique_count']}")
    print(f" Proportions:")
    for category, proportion in stats['proportions'].items():
        print(f" {category}: {proportion:.2%}")
    print(f" Frequency Counts:")
    for category, count in stats['counts'].items():
        print(f" {category}: {count}")
    print("---" * 10)

print(f"\nTask 2 Runtime with Pandas: {task_2_time:.4f} seconds")
# Out:
# Task 2: Summary Statistics with Pandas (for Efficiency Comparison):
#          PREV CLOSE          OPEN          HIGH           LOW          LAST  \
# count  41231.000000  41231.000000  41231.000000  41231.000000  41231.000000
# mean     291.962753    292.350947    296.518484    287.723448    291.993606
# std      452.541028    452.967892    458.224757    447.069432    452.717343
# min        4.900000      4.950000      4.950000      4.800000      4.900000
# 25%       37.150000     37.300000     37.975000     36.450000     37.100000
# 50%      101.900000    102.000000    103.800000     99.800000    101.750000
# 75%      305.675000    306.125000    311.400000    301.050000    305.775000
# max     2860.450000   2871.000000   2896.000000   2838.000000   2861.550000
#
#               CLOSE          VWAP        VOLUME      TURNOVER        TRADES  \
# count  41231.000000  41231.000000  4.123100e+04  4.123100e+04  4.123100e+04
# mean     292.013088    292.160731  1.042650e+07  1.953615e+14  5.221812e+04
# std      452.732064    452.655314  2.953972e+07  4.038675e+14  8.851021e+04
# min        4.900000      4.910000  9.194000e+03  1.681628e+10  9.400000e+01
# 25%       37.100000     37.230000  8.216770e+05  5.730684e+12  5.398000e+03
# 50%      101.850000    102.020000  2.777826e+06  4.025961e+13  1.928000e+04
# 75%      305.675000    306.280000  9.769572e+06  2.041632e+14  6.297200e+04
# max     2860.450000   2867.920000  1.264918e+09  1.498222e+16  1.788274e+06
#
#        DELIVERABLE VOLUME   %DELIVERBLE
# count        4.123100e+04  41231.000000
# mean         3.026935e+06      0.415416
# std          9.387528e+06      0.196122
# min          7.392000e+03      0.020100
# 25%          3.457530e+05      0.252700
# 50%          9.584380e+05      0.414700
# 75%          2.928749e+06      0.563200
# max          7.870864e+08      1.000000
#
# Categorical Summary Statistics:
# SYMBOL:
#  Mode: HDFC
#  Unique Count: 36
#  Proportions:
#  HDFC: 3.24%
#  BANKINDIA: 3.24%
#  KTKBANK: 3.24%
#  J&KBANK: 3.24%
#  SOUTHBANK: 3.24%
#  DCBBANK: 3.24%
#  KARURVYSYA: 3.24%
#  PSB: 3.24%
#  CENTRALBK: 3.24%
#  CUB: 3.24%
#  UCOBANK: 3.24%
#  INDIANB: 3.24%
#  MAHABANK: 3.24%
#  ICICIBANK: 3.24%
#  UNIONBANK: 3.24%
#  FEDERALBNK: 3.24%
#  CANBK: 3.24%
#  IOB: 3.24%
#  SBIN: 3.24%
#  YESBANK: 3.24%
#  KOTAKBANK: 3.24%
#  AXISBANK: 3.24%
#  IDBI: 3.24%
#  INDUSINDBK: 3.24%
#  BANKBARODA: 3.24%
#  PNB: 3.24%
#  DHANBANK: 3.15%
#  RBLBANK: 2.84%
#  AUBANK: 2.33%
#  BANDHANBNK: 1.90%
#  IDFCBANK: 1.82%
#  IDFCFIRSTB: 1.42%
#  CSBBANK: 0.90%
#  UJJIVANSFB: 0.88%
#  EQUITASBNK: 0.34%
#  SURYODAY: 0.10%
#  Frequency Counts:
#  HDFC: 1337
#  BANKINDIA: 1337
#  KTKBANK: 1337
#  J&KBANK: 1337
#  SOUTHBANK: 1337
#  DCBBANK: 1337
#  KARURVYSYA: 1337
#  PSB: 1337
#  CENTRALBK: 1337
#  CUB: 1337
#  UCOBANK: 1337
#  INDIANB: 1337
#  MAHABANK: 1337
#  ICICIBANK: 1337
#  UNIONBANK: 1337
#  FEDERALBNK: 1337
#  CANBK: 1337
#  IOB: 1337
#  SBIN: 1337
#  YESBANK: 1337
#  KOTAKBANK: 1337
#  AXISBANK: 1337
#  IDBI: 1337
#  INDUSINDBK: 1337
#  BANKBARODA: 1337
#  PNB: 1337
#  DHANBANK: 1297
#  RBLBANK: 1173
#  AUBANK: 962
#  BANDHANBNK: 784
#  IDFCBANK: 752
#  IDFCFIRSTB: 585
#  CSBBANK: 370
#  UJJIVANSFB: 364
#  EQUITASBNK: 141
#  SURYODAY: 41
# ------------------------------
#
# Task 2 Runtime with Pandas: 0.2125 seconds

# %%
#Task 2 with duplicate file
import pandas as pd
import time

def calculate_with_pandas(file_path, num_columns, cat_columns):
    """Calculates summary statistics using Pandas for efficiency comparison."""
    start_time = time.time()
    data = pd.read_csv(file_path)

    # Calculate summary statistics for numerical columns
    numerical_summary = data[num_columns].describe()

    # Calculate frequency counts, mode, unique count, and proportions for categorical columns
    categorical_stats = {}
    for col in cat_columns:
        value_counts = data[col].value_counts() # Frequency counts
        total = len(data[col]) # Total rows
        categorical_stats[col] = {
            "mode": value_counts.idxmax(), # Mode (most frequent value)
            "unique_count": value_counts.size, # Count of unique categories
            "proportions": (value_counts / total).to_dict(), # Proportions for each category
            "counts": value_counts.to_dict() # Frequency counts as a dictionary
        }

    task_2_time = time.time() - start_time

    return numerical_summary, categorical_stats, task_2_time

# Task 2 Execution
file_path = 'C:/Users/raksh/OneDrive/Documents/NSE_BANKING_SECTOR_duplicated.csv' #duplicated file
num_columns_stock = ["PREV CLOSE", "OPEN", "HIGH", "LOW", "LAST", "CLOSE", "VWAP", "VOLUME", "TURNOVER", "TRADES", "DELIVERABLE VOLUME", "%DELIVERBLE"]
cat_columns_stock = ["SYMBOL"]

numerical_summary_pandas, categorical_stats_pandas, task_2_time = calculate_with_pandas(file_path, num_columns_stock, cat_columns_stock)

# Display results for Task 2
print("Task 2: Summary Statistics with Pandas (for Efficiency Comparison):")
print(numerical_summary_pandas)

print("\nCategorical Summary Statistics:")
for col, stats in categorical_stats_pandas.items():
    print(f"{col}:")
    print(f" Mode: {stats['mode']}")
    print(f" Unique Count: {stats['unique_count']}")
    print(f" Proportions:")
    for category, proportion in stats['proportions'].items():
        print(f" {category}: {proportion:.2%}")
    print(f" Frequency Counts:")
    for category, count in stats['counts'].items():
        print(f" {category}: {count}")
    print("---" * 10)

print(f"\nTask 2 Runtime with Pandas: {task_2_time:.4f} seconds")
# Out:
# Task 2: Summary Statistics with Pandas (for Efficiency Comparison):
#          PREV CLOSE          OPEN          HIGH           LOW          LAST  \
# count  44910.000000  44910.000000  44910.000000  44910.000000  44910.000000
# mean     370.256455    370.720174    375.659568    365.178596    370.303889
# std      548.599102    549.092707    555.041033    542.302166    548.756418
# min        4.900000      4.950000      4.950000      4.800000      4.900000
# 25%       40.950000     41.100000     41.900000     40.050000     40.950000
# 50%      113.325000    113.500000    115.450000    111.475000    113.200000
# 75%      403.050000    403.100000    411.450000    394.750000    403.212500
# max     2492.300000   2486.000000   2499.900000   2471.800000   2491.700000
#
#               CLOSE          VWAP        VOLUME      TURNOVER        TRADES  \
# count  44910.000000  44910.000000  4.491000e+04  4.491000e+04  4.491000e+04
# mean     370.325563    370.443694  1.035311e+07  2.112588e+14  5.555842e+04
# std      548.771952    548.648067  2.969650e+07  4.076641e+14  8.748389e+04
# min        4.900000      4.910000  9.194000e+03  1.681628e+10  9.400000e+01
# 25%       40.950000     41.020000  9.258712e+05  6.974385e+12  6.213500e+03
# 50%      113.225000    113.475000  2.849380e+06  5.087310e+13  2.280900e+04
# 75%      402.875000    403.080000  9.065008e+06  2.527080e+14  7.245050e+04
# max     2492.300000   2483.170000  1.264918e+09  1.498222e+16  1.788274e+06
#
#        DELIVERABLE VOLUME   %DELIVERBLE
# count        4.491000e+04  44910.000000
# mean         2.923327e+06      0.422247
# std          9.107149e+06      0.202937
# min          7.392000e+03      0.020100
# 25%          3.780618e+05      0.250400
# 50%          1.084482e+06      0.418200
# 75%          2.808343e+06      0.580500
# max          7.870864e+08      1.000000
#
# Categorical Summary Statistics:
# SYMBOL:
#  Mode: HDFC
#  Unique Count: 36
#  Proportions:
#  HDFC: 8.56%
#  BANKBARODA: 5.61%
#  KOTAKBANK: 3.76%
#  IDBI: 3.71%
#  AXISBANK: 3.31%
#  PNB: 3.16%
#  KTKBANK: 2.98%
#  J&KBANK: 2.98%
#  SOUTHBANK: 2.98%
#  MAHABANK: 2.98%
#  DCBBANK: 2.98%
#  KARURVYSYA: 2.98%
#  PSB: 2.98%
#  CENTRALBK: 2.98%
#  CUB: 2.98%
#  UCOBANK: 2.98%
#  INDIANB: 2.98%
#  FEDERALBNK: 2.98%
#  BANKINDIA: 2.98%
#  CANBK: 2.98%
#  IOB: 2.98%
#  YESBANK: 2.98%
#  SBIN: 2.98%
#  UNIONBANK: 2.98%
#  INDUSINDBK: 2.98%
#  DHANBANK: 2.89%
#  RBLBANK: 2.61%
#  AUBANK: 2.14%
#  BANDHANBNK: 1.75%
#  IDFCBANK: 1.67%
#  IDFCFIRSTB: 1.30%
#  ICICIBANK: 0.92%
#  CSBBANK: 0.82%
#  UJJIVANSFB: 0.81%
#  EQUITASBNK: 0.31%
#  SURYODAY: 0.09%
#  Frequency Counts:
#  HDFC: 3844
#  BANKBARODA: 2520
#  KOTAKBANK: 1687
#  IDBI: 1667
#  AXISBANK: 1488
#  PNB: 1418
#  KTKBANK: 1337
#  J&KBANK: 1337
#  SOUTHBANK: 1337
#  MAHABANK: 1337
#  DCBBANK: 1337
#  KARURVYSYA: 1337
#  PSB: 1337
#  CENTRALBK: 1337
#  CUB: 1337
#  UCOBANK: 1337
#  INDIANB: 1337
#  FEDERALBNK: 1337
#  BANKINDIA: 1337
#  CANBK: 1337
#  IOB: 1337
#  YESBANK: 1337
#  SBIN: 1337
#  UNIONBANK: 1337
#  INDUSINDBK: 1337
#  DHANBANK: 1297
#  RBLBANK: 1173
#  AUBANK: 962
#  BANDHANBNK: 784
#  IDFCBANK: 752
#  IDFCFIRSTB: 585
#  ICICIBANK: 414
#  CSBBANK: 370
#  UJJIVANSFB: 364
#  EQUITASBNK: 141
#  SURYODAY: 41
# ------------------------------
#
# Task 2 Runtime with Pandas: 0.2446 seconds

# %%
#Task 3
import csv
import time

# Function to load data from a CSV file
def load_data(file_path):
    """Loads data from a CSV file into a list of rows."""
    data = []
    with open(file_path, 'r') as file:
        reader = csv.reader(file) # Read the file as a CSV
        headers = next(reader) # Save the first row as headers (column names)
        for row in reader: # Read the rest of the rows
            data.append(row)
    return headers, data # Return both headers and the rest of the data

# Function to calculate summary statistics for numerical and categorical columns
def calculate_summary_statistics(data, headers, num_columns, cat_columns):
    """Calculates summary statistics for numerical and categorical columns."""
    # Find the positions (indexes) of the columns in the dataset
    num_col_indices = [headers.index(col) for col in num_columns]
    cat_col_indices = [headers.index(col) for col in cat_columns]

    # Prepare dictionaries to store results
    # Numerical columns: mean, min, max, std, percentiles
    numerical_stats = {col: {'values': []} for col in num_columns}
    # Categorical columns: frequency counts, mode, proportions, unique count
    categorical_stats = {col: {'counts': {}, 'mode': None, 'unique_count': 0, 'proportions': {}} for col in cat_columns}

    # Go through each row of data
    for row in data:
        # Process numerical columns
        for col, idx in zip(num_columns, num_col_indices):
            try:
                value = float(row[idx]) # Convert the value to a number
                numerical_stats[col]['values'].append(value) # Store the value for later calculations
            except ValueError:
                continue # Skip if value is not a valid number

        # Process categorical columns
        for col, idx in zip(cat_columns, cat_col_indices):
            value = row[idx] # Get the value in the column
            if value in categorical_stats[col]['counts']:
                categorical_stats[col]['counts'][value] += 1 # Increment the count for this value
            else:
                categorical_stats[col]['counts'][value] = 1 # Add the value to the dictionary with count 1

    # Calculate statistics for numerical columns
    for col, stats in numerical_stats.items():
        values = stats['values'] # Get the list of all values
        if values: # Only calculate if there are valid values
            stats['mean'] = sum(values) / len(values) # Calculate mean
            stats['min'] = min(values) # Find minimum
            stats['max'] = max(values) # Find maximum
            stats['std'] = (sum((x - stats['mean']) ** 2 for x in values) / len(values)) ** 0.5 # Standard deviation
            sorted_values = sorted(values) # Sort values for percentiles
            stats['25%'] = sorted_values[int(0.25 * len(sorted_values))] # 25th percentile
            stats['50%'] = sorted_values[int(0.5 * len(sorted_values))] # 50th percentile (median)
            stats['75%'] = sorted_values[int(0.75 * len(sorted_values))] # 75th percentile
        else:
            stats.update({'mean': None, 'min': None, 'max': None, 'std': None, '25%': None, '50%': None, '75%': None})

    # Calculate statistics for categorical columns
    for col, stats in categorical_stats.items():
        counts = stats['counts']
        total = sum(counts.values()) # Total occurrences
        if total > 0:
            stats['mode'] = max(counts, key=counts.get) # Most frequent category
            stats['unique_count'] = len(counts) # Count of unique categories
            stats['proportions'] = {key: value / total for key, value in counts.items()} # Proportions for each category

    return numerical_stats, categorical_stats # Return both numerical and categorical stats

# Task 3 Execution with E-commerce Data
file_path_ecommerce = 'C:/Users/raksh/OneDrive/Documents/ecommerce_sales_data.csv'

# Define the numerical and categorical columns for the e-commerce dataset
num_columns_ecommerce = ["Quantity", "Price", "Discount", "CustomerAge", "CustomerLoyaltyScore"]
cat_columns_ecommerce = ["ProductCategory", "PaymentMethod", "CustomerLocation", "CustomerGender", "CustomerIncomeGroup"]

# Load e-commerce data
headers_ecommerce, ecommerce_data = load_data(file_path_ecommerce)

# Start timing for Task 3
start_time = time.time()

# Calculate statistics for e-commerce data
numerical_stats_ecommerce, categorical_stats_ecommerce = calculate_summary_statistics(
    ecommerce_data, headers_ecommerce, num_columns_ecommerce, cat_columns_ecommerce
)

# End timing for Task 3
task_3_time = time.time() - start_time

# Display the summary statistics results for Task 3
print("Task 3: E-commerce Data Summary Statistics (Testing Reusability)")
print("===" * 10)

# Display numerical statistics
for col, stats in numerical_stats_ecommerce.items():
    print(f"{col}:")
    print(f" Mean = {stats['mean']:.2f}, Min = {stats['min']}, Max = {stats['max']}, Std = {stats['std']:.2f}")
    print(f" 25% = {stats['25%']}, 50% (Median) = {stats['50%']}, 75% = {stats['75%']}")
    print("---" * 10)

# Display categorical statistics
print("\nCategorical Summary Statistics:")
for col, stats in categorical_stats_ecommerce.items():
    print(f"{col}:")
    print(f" Mode = {stats['mode']}")
    print(f" Unique Count = {stats['unique_count']}")
    print(f" Proportions:")
    for category, proportion in stats['proportions'].items():
        print(f" {category}: {proportion:.2%}")
    print(f" Frequency Counts:")
    for category, count in stats['counts'].items():
        print(f" {category}: {count}")
    print("---" * 10)

# Display runtime
print(f"\nTask 3 Runtime: {task_3_time:.4f} seconds\n")
# Out:
# Task 3: E-commerce Data Summary Statistics (Testing Reusability)
# ==============================
# Quantity:
#  Mean = 2.50, Min = 1.0, Max = 4.0, Std = 1.12
#  25% = 1.0, 50% (Median) = 3.0, 75% = 3.0
# ------------------------------
# Price:
#  Mean = 501.47, Min = 5.01, Max = 1000.0, Std = 287.54
#  25% = 251.54, 50% (Median) = 501.58, 75% = 750.42
# ------------------------------
# Discount:
#  Mean = 0.15, Min = 0.0, Max = 0.3, Std = 0.09
#  25% = 0.07, 50% (Median) = 0.15, 75% = 0.22
# ------------------------------
# CustomerAge:
#  Mean = 43.38, Min = 18.0, Max = 69.0, Std = 15.03
#  25% = 30.0, 50% (Median) = 43.0, 75% = 56.0
# ------------------------------
# CustomerLoyaltyScore:
#  Mean = 50.00, Min = 0.0, Max = 100.0, Std = 28.89
#  25% = 24.92, 50% (Median) = 49.92, 75% = 75.07
# ------------------------------
#
# Categorical Summary Statistics:
# ProductCategory:
#  Mode = Clothing
#  Unique Count = 7
#  Proportions:
#  Clothing: 14.36%
#  Beauty: 14.28%
#  Toys: 14.30%
#  Electronics: 14.22%
#  Books: 14.34%
#  Sports: 14.20%
#  Home & Kitchen: 14.29%
#  Frequency Counts:
#  Clothing: 14363
#  Beauty: 14277
#  Toys: 14304
#  Electronics: 14221
#  Books: 14342
#  Sports: 14198
#  Home & Kitchen: 14295
# ------------------------------
# PaymentMethod:
#  Mode = Bank Transfer
#  Unique Count = 5
#  Proportions:
#  Cash on Delivery: 19.90%
#  Debit Card: 19.98%
#  Bank Transfer: 20.23%
#  Credit Card: 19.96%
#  PayPal: 19.94%
#  Frequency Counts:
#  Cash on Delivery: 19901
#  Debit Card: 19978
#  Bank Transfer: 20227
#  Credit Card: 19957
#  PayPal: 19937
# ------------------------------
# CustomerLocation:
#  Mode = New Michael
#  Unique Count = 38283
#  Proportions:
#  New Juan: 0.01%
#  South Julie: 0.02%
#  West Carrieview: 0.00%
#  Christianberg: 0.00%
#  South Williamhaven: 0.00%
#  Stephenfort: 0.01%
#  North Terristad: 0.00%
#  Pachecotown: 0.00%
#  Port Philipberg: 0.00%
#  Jenniferfurt: 0.02%
#  Lake Carolyn: 0.01%
#  Amandaborough: 0.01%
#  South Maria: 0.01%
#  West Marissa: 0.00%
#  Austinburgh: 0.01%
#  Lake Jesse: 0.01%
#  Marioburgh: 0.00%
#  Ryanhaven: 0.02%
#  Dickersonmouth: 0.00%
#  Annaborough: 0.01%
#  Ramirezburgh: 0.01%
#  Sextonberg: 0.00%
#  Beasleyshire: 0.00%
#  Lake Brittneyland: 0.00%
#  South John: 0.06%
#  New Devin: 0.01%
#  Lake Denise: 0.01%
#  South Susan: 0.02%
#  Johnsonchester: 0.04%
#  Martinberg: 0.01%
#  Lake Billy: 0.00%
#  Josephborough: 0.01%
#  Noahbury: 0.00%
#  Bowmanport: 0.00%
#  South Melvinville: 0.00%
#  East Brittany: 0.02%
#  Lake Stephaniefurt: 0.00%
#  North Adam: 0.01%
#  Sancheztown: 0.01%
#  Burtonmouth: 0.01%
#  Lake Josephmouth: 0.01%
#  Clarkeville: 0.00%
#  Christopherside: 0.02%
#  Deborahton: 0.01%
#  Ewingbury: 0.00%
#  Michelleborough: 0.01%
#  South Cathy: 0.01%
#  Garciaburgh: 0.01%
#  Berryfort: 0.00%
#  East Davidburgh: 0.01%
#  Brownchester: 0.02%
#  Tammyshire: 0.01%
#  Morganmouth: 0.01%
#  North Laurahaven: 0.00%
#  Matthewland: 0.02%
#  Adrienneberg: 0.00%
#  Hamiltonburgh: 0.00%
#  West Victor: 0.00%
#  Wesleyborough: 0.00%
#  Fischermouth: 0.01%
#  Lawrencefurt: 0.01%
#  North Louis: 0.00%
#  Michaelside: 0.03%
#  West Cindyborough: 0.00%
#  Mariachester: 0.01%
#  Dianeshire: 0.01%
#  Davismouth: 0.02%
#  East Courtneyview: 0.00%
#  Cameronmouth: 0.01%
#  West Arthur: 0.00%
#  Frenchfurt: 0.00%
#  North Keithbury: 0.00%
#  Wrightland: 0.01%
#  South Deborahtown: 0.00%
#  Hernandezside: 0.01%
#  North Leetown: 0.00%
#  East Alexanderbury: 0.00%
#  Penningtonport: 0.00%
#  North Bobbyburgh: 0.00%
#  Jenniferton: 0.02%
#  Brandonberg: 0.01%
#  Joshuafurt: 0.01%
#  Myersshire: 0.00%
#  Taylorchester: 0.01%
#  North Teresa: 0.01%
#  Deborahview: 0.01%
#  Melissamouth: 0.02%
#  Powellmouth: 0.01%
#  Stevenview: 0.01%
#  East Christopher: 0.06%
#  Smithside: 0.03%
#  Obrienstad: 0.00%
#  Lisaburgh: 0.01%
#  Kathleenstad: 0.01%
#  East Juanhaven: 0.00%
#  New Jeffrey: 0.02%
#  Barbaratown: 0.00%
#  Silvachester: 0.01%
#  East Jessica: 0.04%
#  New Sean: 0.01%
#  Blackmouth: 0.00%
#  Summersstad: 0.00%
#  Millerview: 0.02%
#  North Michaelborough: 0.01%
#  Mcgeebury: 0.00%
#  South Mark: 0.02%
#  New Daniel: 0.04%
#  South Karaside: 0.00%
#  New Laurastad: 0.00%
#  Rodriguezfurt: 0.01%
#  Tammymouth: 0.01%
#  Tuckershire: 0.00%
#  Wilkinstown: 0.00%
#  East Dawn: 0.01%
#  Port Anna: 0.01%
#  Greenstad: 0.01%
#  Brendafurt: 0.01%
#  Port Joseph: 0.03%
#  Frankberg: 0.00%
#  Wilkinsberg: 0.00%
#  Mathewsshire: 0.00%
#  New Kaitlyn: 0.01%
#  Lake Gregory: 0.01%
#  Port Timothy: 0.03%
#  New Aaronville: 0.00%
#  Stevenchester: 0.01%
#  Carpentertown: 0.00%
#  Snyderburgh: 0.00%
#  Lake Amber: 0.02%
#  Port Michael: 0.08%
#  Valentineview: 0.00%
#  North Donnaland: 0.00%
#  North Rhonda: 0.01%
#  Jeremymouth: 0.00%
#  West Julia: 0.01%
#  Jonesville: 0.01%
#  Connerborough: 0.00%
#  Susanton: 0.01%
#  North Dana: 0.01%
#  Rebeccaberg: 0.01%
#  New Jennifermouth: 0.01%
#  Scottside: 0.01%
#  West Elizabeth: 0.03%
#  New Michelle: 0.03%
#  Cruzmouth: 0.01%
#  Port Andreaport: 0.00%
#  Mejiamouth: 0.00%
#  Jeffreychester: 0.01%
#  North Maureen: 0.00%
#  New Matthewborough: 0.00%
#  South Maryfort: 0.00%
#  Port Sarah: 0.03%
#  Triciashire: 0.00%
#  Port Daniel: 0.04%
#  Danielfurt: 0.01%
#  Angelaland: 0.01%
#  New Valerieside: 0.00%
#  Port Kennethburgh: 0.00%
#  Stevensmouth: 0.01%
#  Dustinfort: 0.00%
#  Aaronstad: 0.01%
#  Stoutland: 0.00%
#  East Derektown: 0.00%
#  New Omarside: 0.00%
#  Port Cheryl: 0.01%
#  East Garymouth: 0.00%
#  North Amy: 0.02%
#  Lake Sean: 0.01%
#  New Christopher: 0.05%
#  New Dawn: 0.01%
#  Dannyborough: 0.00%
#  Serranoview: 0.00%
#  Port Sethton: 0.00%
#  Mathewsstad: 0.00%
#  West Ashley: 0.02%
#  New Gina: 0.01%
#  North Patricia: 0.02%
#  New Stephanie: 0.02%
#  New Justinfort: 0.00%
#  Montoyaland: 0.00%
#  West Aaron: 0.01%
#  Port Jameston: 0.00%
#  South Heather: 0.01%
#  Lake Shannonfurt: 0.00%
#  East Anthonymouth: 0.00%
#  Maryfort: 0.01%
#  Jenniferview: 0.02%
#  Campbellton: 0.00%
#  Robinsonside: 0.01%
#  West Juanfort: 0.00%
#  Lake Andrea: 0.01%
#  Mercerburgh: 0.00%
#  East Nicole: 0.01%
#  North Michael: 0.08%
#  Barnesport: 0.01%
#  Geraldtown: 0.00%
#  Vickieborough: 0.00%
#  North Randyshire: 0.00%
#  Charlesborough: 0.01%
#  Sherrymouth: 0.01%
#  Burtonberg: 0.00%
#  Brownberg: 0.02%
#  North Miguelmouth: 0.00%
#  Powelltown: 0.00%
#  Bakerbury: 0.01%
#  Teresaland: 0.00%
#  Tomport: 0.00%
#  Bakerfurt: 0.01%
#  Fosterton: 0.00%
#  Dorisstad: 0.00%
#  Jeremyborough: 0.01%
#  West Susan: 0.02%
#  Caseyfurt: 0.00%
#  West Melissaville: 0.00%
#  South Aaron: 0.01%
#  Lake Erinchester: 0.00%
#  Cherylberg: 0.01%
#  Brownview: 0.02%
#  Williamstown: 0.01%
#  West Laurenfurt: 0.00%
#  Yvonnemouth: 0.00%
#  Katieberg: 0.00%
#  South Jeffreyton: 0.00%
#  Maryville: 0.01%
#  East Frankshire: 0.00%
#  Ramirezberg: 0.01%
#  Gatesville: 0.00%
#  Margarettown: 0.00%
#  East Christine: 0.02%
#  Natalietown: 0.00%
#  South Jason: 0.04%
#  Shawside: 0.01%
#  Shepherdstad: 0.00%
#  Michaelland: 0.04%
#  Munozport: 0.00%
#  Sotofurt: 0.00%
#  Katieborough: 0.00%
#  Port Annemouth: 0.00%
#  West Benjamintown: 0.00%
#  Richardsonborough: 0.01%
#  Jenkinsborough: 0.00%
#  Aprilborough: 0.00%
#  Annmouth: 0.01%
#  Lake Madisontown: 0.00%
#  West Christopher: 0.05%
#  Lake Josephton: 0.00%
#  Rothbury: 0.00%
#  Robinsonville: 0.01%
#  Bellfort: 0.01%
#  Allenstad: 0.01%
#  Patelfort: 0.00%
#  North William: 0.03%
#  Kathrynhaven: 0.01%
#  West Teresafurt: 0.00%
#  New Derek: 0.01%
#  South Michael: 0.08%
#  North Ivan: 0.00%
#  Johnborough: 0.02%
#  Greeneshire: 0.00%
#  Chadbury: 0.01%
#  Meganchester: 0.01%
#  West Annettestad: 0.00%
#  New Josephtown: 0.00%
#  Ellisview: 0.00%
#  Johnathanmouth: 0.00%
#  Raybury: 0.00%
#  Villegasburgh: 0.00%
#  Traceyton: 0.00%
#  Robertville: 0.02%
#  Lake Alicia: 0.00%
#  Lake Evanfort: 0.00%
#  Juliemouth: 0.01%
#  Lucerobury: 0.00%
#  West Michaelland: 0.01%
#  Kimberlyland: 0.01%
#  Justinborough: 0.01%
#  North Taylor: 0.00%
#  Lake Deniseport: 0.00%
#  Shellyport: 0.00%
#  Port Alexmouth: 0.00%
#  South Jamesburgh: 0.00%
#  Webbtown: 0.00%
#  Davisview: 0.02%
#  Jenkinsfurt: 0.00%
#  Tracymouth: 0.01%
#  North Nicole: 0.02%
#  South Jeremiahtown: 0.00%
#  East Katrinaburgh: 0.00%
#  North Megan: 0.01%
#  Lake Jonathan: 0.03%
#  South Emilyborough: 0.00%
#  East Ana: 0.00%
#  East Larry: 0.01%
#  Port Sandra: 0.01%
#  Cookchester: 0.00%
#  Port Selena: 0.00%
#  Courtneyfurt: 0.00%
#  Valeriehaven: 0.00%
#  East Laurenshire: 0.00%
#  Lisamouth: 0.03%
#  East Deborah: 0.01%
#  West Catherine: 0.01%
#  South Amandahaven: 0.00%
#  Port Nathan: 0.01%
#  South Amanda: 0.03%
#  Port Jenniferberg: 0.00%
#  Lake Christophermouth: 0.01%
#  Westview: 0.01%
#  Rhondaberg: 0.00%
#  West Timothy: 0.02%
#  North Kevin: 0.02%
#  Port Anthony: 0.03%
#  Lake Johnmouth: 0.01%
#  Morganborough: 0.01%
#  Port Andre: 0.00%
#  Jenniferberg: 0.02%
#  East Michael: 0.08%
#  East Georgeland: 0.00%
#  Lake Allisonside: 0.00%
#  Jacksonfurt: 0.01%
#  South Jose: 0.01%
#  East Joshuaville: 0.00%
#  North Christophertown: 0.01%
#  Port Charles: 0.02%
#  Port Barbara: 0.01%
#  New Michaelburgh: 0.00%
#  Port Matthewshire: 0.00%
#  Michaelburgh: 0.03%
#  Port Markburgh: 0.00%
#  Danahaven: 0.00%
#  New Heatherton: 0.00%
#  Lake Kathleen: 0.01%
#  South Kristen: 0.01%
#  Ashleyhaven: 0.01%
#  Johnmouth: 0.03%
#  North Daniellefort: 0.00%
#  Georgechester: 0.01%
#  West Christinamouth: 0.00%
#  West Rachelland: 0.00%
#  North Andrew: 0.03%
#  Wisechester: 0.00%
#  Franklinmouth: 0.01%
#  Port Desireestad: 0.00%
#  Kimhaven: 0.00%
#  Port Sharifurt: 0.00%
#  Matthewtown: 0.02%
#  Fuenteston: 0.00%
#  Port Melissa: 0.03%
#  Lake Meganborough: 0.00%
#  Port Danielview: 0.00%
#  Port Latoya: 0.00%
#  Reedhaven: 0.00%
#  Tannerfort: 0.00%
#  West Leslie: 0.01%
#  Patriciamouth: 0.01%
#  Lake Mark: 0.03%
#  North Andrewbury: 0.00%
#  Carlostown: 0.00%
#  Jacobfurt: 0.00%
#  Lake Megan: 0.01%
#  Whitefurt: 0.01%
#  North Ian: 0.00%
#  Barronberg: 0.00%
#  Luceroburgh: 0.00%
#  Alexanderborough: 0.01%
#  Stephenschester: 0.00%
#  Aguilarland: 0.00%
#  Brownshire: 0.02%
#  Marystad: 0.01%
#  Sloanmouth: 0.00%
#  Chapmanfurt: 0.00%
#  Cartershire: 0.01%
#  Rogermouth: 0.00%
#  North Jacquelineside: 0.00%
#  Lake Michaelborough: 0.01%
#  Paulbury: 0.01%
#  Stoutview: 0.00%
#  Jasonburgh: 0.01%
#  South Karen: 0.01%
#  Jacksonfort: 0.01%
#  North Stevenburgh: 0.00%
#  Fowlerland: 0.00%
#  Port Davidchester: 0.01%
#  East Kathleenchester: 0.00%
#  North Ariel: 0.00%
#  Lake Jenniferland: 0.00%
#  New Jennifer: 0.05%
#  Woodshire: 0.00%
#  North Matthewland: 0.00%
#  West Melissaberg: 0.00%
#  East Sarah: 0.02%
#  Nathanielshire: 0.00%
#  North Tara: 0.01%
#  East Rose: 0.00%
#  Lopezberg: 0.01%
#  New James: 0.04%
#  New Travis: 0.01%
#  Joneston: 0.01%
#  Hinesshire: 0.00%
#  Darrellstad: 0.00%
#  Theresachester: 0.00%
#  Patriciatown: 0.01%
#  Kennethport: 0.01%
#  West Jasonburgh: 0.00%
#  New Jamie: 0.01%
#  Alexandriaberg: 0.00%
#  Port Rebekahfurt: 0.00%
#  Lake Gregoryberg: 0.00%
#  South Bryan: 0.00%
#  North Kimberlyton: 0.00%
#  East Kevinmouth: 0.00%
#  South Robertberg: 0.00%
#  Ryanberg: 0.01%
#  Seanfort: 0.00%
#  New Bettyland: 0.00%
#  Andersonhaven: 0.01%
#  East Latashaside: 0.00%
#  West Danielleland: 0.00%
#  Austinland: 0.00%
#  Walkerfort: 0.01%
#  Port Madison: 0.01%
#  Josephburgh: 0.01%
#  West Timothyborough: 0.00%
#  North Adrian: 0.00%
#  West Brenda: 0.01%
#  Dannyview: 0.00%
#  Figueroachester: 0.00%
#  Richardsstad: 0.00%
#  Jacobsonport: 0.00%
#  Romeroport: 0.00%
#  South Brandon: 0.01%
#  Gordonfort: 0.01%
#  Port John: 0.06%
#  Scottfort: 0.01%
#  Alanfort: 0.00%
#  South Stacy: 0.00%
#  New Lindachester: 0.00%
#  North Lisa: 0.03%
#  Richardsonhaven: 0.00%
#  North Spencer: 0.00%
#  Danielton: 0.01%
#  North Stephanieborough: 0.00%
#  Bellport: 0.01%
#  Sabrinatown: 0.00%
#  South James: 0.05%
#  Clementsmouth: 0.00%
#  Drewburgh: 0.00%
#  Port Alexandraside: 0.00%
#  Christopherton: 0.03%
#  East Patricia: 0.01%
#  Ellisburgh: 0.00%
#  Lake Nicholas: 0.01%
#  South Tamara: 0.01%
#  Parsonsborough: 0.00%
#  New Sherrybury: 0.00%
#  Lake Stefaniemouth: 0.00%
#  Garybury: 0.00%
#  Lake Karaland: 0.00%
#  Lake Adamburgh: 0.00%
#  Perezchester: 0.01%
#  Taylorborough: 0.01%
#  South Ronaldport: 0.00%
#  West Clinton: 0.00%
#  South Amy: 0.03%
#  Phyllisfurt: 0.00%
#  Port Angelatown: 0.00%
#  Anthonyport: 0.01%
#  North Cynthialand: 0.00%
#  Estradatown: 0.00%
#  Lake Kylefort: 0.00%
#  Johnsonmouth: 0.04%
#  Port Erik: 0.00%
#  Briannahaven: 0.00%
#  Port Alexiston: 0.00%
#  Tracieton: 0.00%
#  New Patrickview: 0.00%
#  Jaychester: 0.00%
#  Jonathanhaven: 0.01%
#  Janetville: 0.00%
#  Marybury: 0.01%
#  Clementsshire: 0.00%
#  Lake Mitchellstad: 0.00%
#  East Davidborough: 0.01%
#  Palmerberg: 0.00%
#  Tiffanyshire: 0.01%
#  Aprilfort: 0.00%
#  Maryside: 0.00%
#  Williamsside: 0.03%
#  Lake Adamstad: 0.00%
#  Lorimouth: 0.01%
#  Evanston: 0.01%
#  Michaelshire: 0.03%
#  Josephmouth: 0.03%
#  Greenmouth: 0.01%
#  Port Stevenberg: 0.00%
#  Cooleybury: 0.00%
#  Lake Kimberlymouth: 0.00%
#  North Kendrafurt: 0.00%
#  Grahamstad: 0.01%
#  Harrisonview: 0.01%
#  North Gregorystad: 0.00%
#  West Jerry: 0.01%
#  Cooperchester: 0.01%
#  Kristaview: 0.00%
#  Port Theresaland: 0.00%
#  Hoffmanton: 0.00%
#  North Nicolehaven: 0.00%
#  Andersonville: 0.01%
#  Erinton: 0.01%
#  West Anthony: 0.04%
#  Lorifort: 0.01%
#  South William: 0.05%
#  Taylortown: 0.01%
#  Tanyashire: 0.00%
#  Westborough: 0.00%
#  Port Lauren: 0.01%
#  West Bobshire: 0.00%
#  East Coreyfurt: 0.00%
#  East Nicholasville: 0.00%
#  South Carolchester: 0.00%
#  East Cameronberg: 0.00%
#  Petermouth: 0.01%
#  Kimberlyton: 0.01%
#  Benjaminport: 0.01%
#  Frenchmouth: 0.00%
#  New Richardfurt: 0.00%
#  Thomasfurt: 0.02%
#  West Colin: 0.00%
#  New Jorgebury: 0.00%
#  East Samuel: 0.01%
#  Port Micheleport: 0.00%
#  East Hannah: 0.01%
#  Carterfurt: 0.01%
#  New Rachelmouth: 0.00%
#  Owensside: 0.00%
#  West Sarahland: 0.00%
#  Port Rebecca: 0.03%
#  Lake Christian: 0.01%
#  Tonyborough: 0.00%
#  Charlesmouth: 0.01%
#  Carriestad: 0.00%
#  Port Nathanfurt: 0.00%
#  Garrisonview: 0.00%
#  South Benjaminmouth: 0.00%
#  Fernandezstad: 0.00%
#  Lake Alisonfurt: 0.00%
#  Carrieburgh: 0.00%
#  New Stephen: 0.01%
#  Garciachester: 0.01%
#  Henryfurt: 0.00%
#  Lake Allisonmouth: 0.00%
#  New Erica: 0.01%
#  Lake Jeanmouth: 0.00%
#  Lake Kimberlyshire: 0.00%
#  Lake Travis: 0.01%
#  Port Shawnside: 0.00%
#  West Christieport: 0.00%
#  Lake Shelbyland: 0.00%
#  Barberview: 0.00%
#  West Gabrielberg: 0.00%
#  West Danielberg: 0.00%
#  West Susanton: 0.00%
#  West Adamport: 0.00%
#  Robertsburgh: 0.01%
#  Hernandeztown: 0.01%
#  Dannyfort: 0.00%
#  Maryfurt: 0.01%
#  Coreychester: 0.00%
#  Nicolemouth: 0.01%
#  Elizabethchester: 0.01%
#  Lake Kenneth: 0.02%
#  North Gregory: 0.01%
#  East Danielfort: 0.00%
#  Leeshire: 0.01%
#  Lake Kylietown: 0.00%
#  Lake Shannon: 0.01%
#  South Linda: 0.01%
#  Joshuamouth: 0.02%
#  Lake Erica: 0.01%
#  Pattersonview: 0.00%
#  East Dominiquebury: 0.00%
#  Wendymouth: 0.01%
#  West Wayneville: 0.00%
#  Lake Dianamouth: 0.00%
#  Solomontown: 0.00%
#  Cherylton: 0.00%
#  Patriciahaven: 0.01%
#  Mandyland: 0.00%
#  Brownstad: 0.02%
#  Greenton: 0.01%
#  Kennethmouth: 0.01%
#  Meganshire: 0.01%
#  Zacharychester: 0.01%
#  Bushhaven: 0.00%
#  Morganstad: 0.01%
#  Mooreshire: 0.02%
#  West Davidfurt: 0.00%
#  Lopezstad: 0.01%
#  Lake Samanthafort: 0.00%
#  Marychester: 0.01%
#  Port Aaron: 0.01%
#  Burketown: 0.00%
#  New Stacyside: 0.00%
#  Kellybury: 0.01%
#  Smithshire: 0.04%
#  Sanchezville: 0.01%
#  North Sarah: 0.03%
#  South Brian: 0.03%
#  Sheltonmouth: 0.01%
#  Feliciafort: 0.00%
#  Barberland: 0.00%
#  Porterstad: 0.00%
#  Lake Aaron: 0.01%
#  Allenbury: 0.01%
#  Kristinachester: 0.00%
#  Sarahside: 0.01%
#  West Nicolemouth: 0.00%
#  New William: 0.05%
#  Jeffreyland: 0.01%
#  Cherylfurt: 0.00%
#  Cuevasmouth: 0.00%
#  Lake Elizabethfort: 0.00%
#  Joelville: 0.00%
#  East Chadchester: 0.00%
#  New Christopherville: 0.00%
#  West Melissatown: 0.00%
#  Port Rhonda: 0.01%
#  Keithmouth: 0.01%
#  Davidstad: 0.02%
#  Frankstad: 0.00%
#  Anitaberg: 0.00%
#  Port Maria: 0.02%
#  North Richardfurt: 0.00%
#  Johnside: 0.03%
#  East Joel: 0.01%
#  Lisaville: 0.02%
#  New Heather: 0.02%
#  New Molly: 0.01%
#  South Brianhaven: 0.00%
#  Shawnchester: 0.01%
#  North Jeremy: 0.01%
#  New Jacqueline: 0.01%
#  Kimberlyshire: 0.01%
#  North Thomasville: 0.00%
#  Maryton: 0.01%
#  South Kaylaton: 0.00%
#  New Adrian: 0.00%
#  Stephensonborough: 0.00%
#  Marcusmouth: 0.01%
#  Jamesfurt: 0.03%
#  Hortonville: 0.00%
#  Lake Thomasstad: 0.00%
#  Riceport: 0.00%
#  East Keithview: 0.00%
#  Dustinberg: 0.00%
#  Leeport: 0.01%
#  West Johnview: 0.00%
#  Hullberg: 0.00%
#  Vazquezfort: 0.00%
#  Lake Pattybury: 0.00%
#  Banksfurt: 0.00%
#  Cortezberg: 0.00%
#  North Francesfort: 0.00%
#  Diazchester: 0.00%
#  Sharpchester: 0.00%
#  Brownfurt: 0.02%
#  Michellebury: 0.01%
#  Millermouth: 0.02%
#  Andrewsport: 0.00%
#  Jeremyland: 0.01%
#  Jacksonberg: 0.01%
#  Burnsfurt: 0.00%
#  Scottberg: 0.01%
#  Dylanhaven: 0.00%
#  Jacobsonburgh: 0.00%
#  Valenzuelahaven: 0.00%
#  Nunezside: 0.00%
#  West Brian: 0.03%
#  Angelaborough: 0.01%
#  Lake Jason: 0.02%
#  Lake Michael: 0.09%
#  New Tylermouth: 0.00%
#  Port Richard: 0.03%
#  West Debbie: 0.00%
#  Jeffreystad: 0.01%
#  Lake Richardfurt: 0.00%
#  Walkerborough: 0.01%
#  Davidbury: 0.02%
#  Vazquezmouth: 0.00%
#  East Ann: 0.00%
#  Clarkbury: 0.01%
#  Robertmouth: 0.03%
#  West Nathan: 0.01%
#  Williambury: 0.01%
#  Meganburgh: 0.00%
#  Martinbury: 0.01%
#  North John: 0.06%
#  North Christopher: 0.05%
#  Andersonbury: 0.01%
#  Jerrychester: 0.01%
#  Robertfort: 0.02%
#  Fieldsshire: 0.00%
#  North Katherine: 0.01%
#  Curtismouth: 0.00%
#  New Cherylberg: 0.00%
#  Lake Jesus: 0.01%
#  Daltonberg: 0.00%
#  Mooreburgh: 0.01%
#  Andersenburgh: 0.00%
#  Veronicamouth: 0.01%
#  Heidifurt: 0.00%
#  Thompsonstad: 0.01%
#  West Sarah: 0.01%
#  Blairside: 0.00%
#  New Misty: 0.00%
#  Underwoodhaven: 0.00%
#  New Cynthiaville: 0.00%
#  Heatherfort: 0.01%
#  South Roy: 0.00%
#  East Fred: 0.00%
#  Paulaborough: 0.00%
#  Johnsonside: 0.03%
#  West Jorge: 0.00%
#  West Joeside: 0.00%
#  Port Elizabethtown: 0.00%
#  Smallland: 0.00%
#  Nelsonport: 0.01%
#  Lake Shannonfort: 0.00%
#  East Philipborough: 0.00%
#  Port Jillianmouth: 0.00%
#  East Bethside: 0.00%
#  Whitakerfort: 0.00%
#  Nicolechester: 0.01%
#  Lake Rachelbury: 0.00%
#  West Natasha: 0.00%
#  Jessicamouth: 0.01%
#  North Kevinbury: 0.00%
#  East Hector: 0.00%
#  West Williamside: 0.00%
#  Danielletown: 0.00%
#  Morenoville: 0.00%
#  Erictown: 0.01%
#  Zoefort: 0.00%
#  Lake Josephbury: 0.00%
#  Lake Marytown: 0.00%
#  New Stacy: 0.01%
#  Michaelhaven: 0.03%
#  Jeffreymouth: 0.01%
#  Jillfurt: 0.01%
#  Underwoodfort: 0.00%
#  Whiteland: 0.01%
#  South Kimberly: 0.03%
#  Lake Tinamouth: 0.00%
#  Port Jacquelineside: 0.00%
#  Mejiastad: 0.00%
#  Lake Melvinview: 0.00%
#  Kimton: 0.01%
#  Robertland: 0.02%
#  New Victoria: 0.01%
#  Smithbury: 0.03%
#  Lake Joseph: 0.03%
#  Lake Karen: 0.02%
#  New Staceyberg: 0.00%
#  East Maria: 0.01%
#  Edwardborough: 0.00%
#  Bentleyshire: 0.00%
#  Lake Benjaminfort: 0.00%
#  Contrerasfort: 0.00%
#  Lesliebury: 0.00%
#  Bentleyborough: 0.00%
#  Port Kathleen: 0.01%
#  Carolmouth: 0.00%
#  South Connietown: 0.00%
#  Sethhaven: 0.00%
#  West Rachel: 0.01%
#  West Brent: 0.00%
#  Vickiefort: 0.00%
#  Brownton: 0.02%
#  Gonzalezview: 0.01%
#  Kramertown: 0.00%
#  Gilbertborough: 0.00%
#  West Susanmouth: 0.01%
#  Carolstad: 0.00%
#  West Jacqueline: 0.01%
#  West Jasonhaven: 0.00%
#  South Dawn: 0.01%
#  East Arthur: 0.00%
#  West Derrickborough: 0.00%
#  Lake Stevenside: 0.00%
#  East Gregory: 0.01%
#  Mcphersonland: 0.00%
#  Farrellstad: 0.00%
#  Port Christinamouth: 0.00%
#  Port Brandon: 0.02%
#  Jonathanville: 0.01%
#  Johnhaven: 0.02%
#  New Morgan: 0.01%
#  Lake Codyview: 0.00%
#  South Joshuaville: 0.00%
#  Haleychester: 0.00%
#  Lake Victoriachester: 0.00%
#  East Douglas: 0.01%
#  North Patriciaton: 0.00%
#  Lindamouth: 0.01%
#  East Misty: 0.00%
#  Lake William: 0.03%
#  New Ashleyland: 0.00%
#  Luisberg: 0.00%
#  Karenmouth: 0.02%
#  Hallshire: 0.01%
#  West Deborah: 0.01%
#  Rowlandfurt: 0.00%
#  Alexisland: 0.00%
#  Patrickmouth: 0.01%
#  Kimberlyborough: 0.01%
#  West Jennifer: 0.06%
#  South Melissa: 0.03%
#  Lorraineborough: 0.00%
#  East Kristaburgh: 0.00%
#  East Christon: 0.00%
#  North Shanetown: 0.00%
#  West Michelle: 0.04%
#  North George: 0.01%
#  Susanfurt: 0.01%
#  Robertton: 0.02%
#  North Bryan: 0.00%
#  West Audreyburgh: 0.00%
#  Johnport: 0.02%
#  Aliciaport: 0.00%
#  West Marymouth: 0.00%
#  Port Andrewfort: 0.00%
#  East Peter: 0.01%
#  New Joshualand: 0.00%
#  Joshuaville: 0.01%
#  Carsonton: 0.00%
#  North Melissa: 0.03%
#  New Antonioport: 0.00%
#  Port Ianburgh: 0.00%
#  North Benjamin: 0.01%
#  Delgadotown: 0.00%
#  East Shirleytown: 0.00%
#  Kleinchester: 0.00%
#  Sarahtown: 0.01%
#  Kathyborough: 0.00%
#  North James: 0.05%
#  Stevensfort: 0.00%
#  Lake Julieborough: 0.00%
#  Lynchview: 0.00%
#  West Adrian: 0.01%
#  East Robert: 0.06%
#  Ricehaven: 0.00%
#  East Heather: 0.02%
#  North Ronald: 0.01%
#  North Nicolechester: 0.00%
#  Kaiserland: 0.00%
#  Jasonfort: 0.01%
#  Port Ebonyville: 0.00%
#  Williammouth: 0.03%
#  South Johnton: 0.00%
#  Mendozaville: 0.00%
#  North Kathrynville: 0.00%
#  West Shelly: 0.00%
#  Allenburgh: 0.01%
#  Frankhaven: 0.01%
#  Catherineborough: 0.00%
#  Riggsview: 0.00%
#  Ericaberg: 0.01%
#  Bennettfurt: 0.00%
#  Bobbyburgh: 0.00%
#  West Kathryn: 0.01%
#  Kimberlyburgh: 0.01%
#  Martinezhaven: 0.01%
#  New Lisa: 0.03%
#  Beanburgh: 0.00%
#  Jonesberg: 0.02%
#  Kristenfort: 0.00%
#  Port Ann: 0.01%
#  Port Robert: 0.04%
#  Port Travisfurt: 0.00%
#  West Kevinmouth: 0.01%
#  Natalieshire: 0.00%
#  New Davidmouth: 0.00%
#  Christopherfort: 0.02%
#  South Michelleview: 0.00%
#  Newmanberg: 0.00%
#  Lake Paulland: 0.00%
#  Nicoleview: 0.01%
#  Haleyberg: 0.00%
#  East Sarahside: 0.00%
#  North Annatown: 0.00%
#  Emilyburgh: 0.00%
#  Port Maurice: 0.00%
#  West Jasonton: 0.00%
#  Lozanoport: 0.00%
#  Schmidttown: 0.00%
#  New Amyfurt: 0.00%
#  West Katherine: 0.01%
#  North Valerie: 0.01%
#  Lake Alice: 0.00%
#  Farmerland: 0.00%
#  Kimshire: 0.01%
#  Ambermouth: 0.01%
#  West Codychester: 0.00%
#  Gutierrezmouth: 0.00%
#  Port Dale: 0.00%
#  South Lauren: 0.02%
#  Lauraton: 0.01%
#  Lisahaven: 0.01%
#  North Samuelmouth: 0.00%
#  Joelport: 0.00%
#  Wilsonborough: 0.01%
#  Albertport: 0.00%
#  Stonestad: 0.00%
#  North Sethmouth: 0.00%
#  South Karenmouth: 0.00%
#  Tracyberg: 0.01%
#  Nicholasville: 0.01%
#  South Scott: 0.01%
#  Tomborough: 0.00%
#  Hendricksland: 0.00%
#  South Daniel: 0.04%
#  Jamiemouth: 0.01%
#  Alexisshire: 0.00%
#  Davisfurt: 0.01%
#  Crystalland: 0.01%
#  Port Carrie: 0.01%
#  Gregoryborough: 0.01%
#  East Sherrihaven: 0.00%
#  New Scott: 0.02%
#  Paulfurt: 0.01%
#  Port Paulland: 0.00%
#  Butlershire: 0.01%
#  Graymouth: 0.01%
#  East Lauraberg: 0.00%
#  Lake Danielleland: 0.00%
#  South Andrea: 0.01%
#  Davenportport: 0.00%
#  Joshuabury: 0.02%
#  Amberview: 0.01%
#  Leeborough: 0.01%
#  North Anthonyport: 0.00%
#  Carrollmouth: 0.00%
#  Port Sheena: 0.00%
#  North David: 0.06%
#  Lake Kristen: 0.01%
#  West David: 0.06%
#  Jonesland: 0.02%
#  South Kevinport: 0.00%
#  Crawfordside: 0.00%
#  North Tammyhaven: 0.00%
#  Davidton: 0.02%
#  East Teresa: 0.01%
#  Montgomeryfort: 0.00%
#  Lake Kimberlyburgh: 0.00%
#  West Kyle: 0.02%
#  West Brianmouth: 0.00%
#  Danielmouth: 0.02%
#  New Sarah: 0.02%
#  Port Eileenton: 0.00%
#  New Neil: 0.00%
#  Marvinville: 0.00%
#  Port Haleyshire: 0.00%
#  New Markchester: 0.00%
#  Christinefurt: 0.01%
#  North Samanthaton: 0.00%
#  Medinafort: 0.00%
#  Lake Andrew: 0.03%
#  Cohentown: 0.00%
#  New Matthew: 0.04%
#  Kristineberg: 0.00%
#  Allisonview: 0.00%
#  Hernandezton: 0.01%
#  New Mark: 0.02%
#  Lake Kaitlin: 0.00%
#  Howellfurt: 0.00%
#  Port Jean: 0.00%
#  Ryanfort: 0.01%
#  East Monicaberg: 0.00%
#  Port Denise: 0.01%
#  Port Alexishaven: 0.00%
#  North Nancy: 0.01%
#  Lake Lisa: 0.03%
#  West Kimberly: 0.03%
#  South Jennifer: 0.05%
#  North Michaelport: 0.00%
#  South Katelynland: 0.00%
#  West Mary: 0.04%
#  Lake Patricia: 0.02%
#  Lake Mary: 0.03%
#  Andrewview: 0.01%
#  West James: 0.06%
#  West Jack: 0.01%
#  Smithchester: 0.04%
#  North Kristen: 0.01%
#  South Jeffrey: 0.02%
#  West Carlos: 0.00%
#  New Shawn: 0.01%
#  South Jasontown: 0.00%
#  Dodsonbury: 0.00%
#  Richmondfurt: 0.00%
#  Mooreborough: 0.01%
#  Churchfort: 0.00%
#  Gardnertown: 0.00%
#  Port Jayborough: 0.00%
#  Port Amychester: 0.00%
#  Kingside: 0.01%
#  Flemingberg: 0.00%
#  Reginamouth: 0.01%
#  Cookbury: 0.00%
#  East Tylerfort: 0.00%
#  New Leslieview: 0.00%
#  East Heatherville: 0.00%
#  East Keithfurt: 0.00%
#  Port Deborah: 0.01%
#  West Amandaburgh: 0.00%
#  New Darrell: 0.00%
#  Hobury: 0.00%
#  Lake Brandiborough: 0.00%
#  West Jillian: 0.00%
#  Cantuberg: 0.00%
#  Brendaton: 0.01%
#  East Aaron: 0.01%
#  Port Juliemouth: 0.00%
#  Padillaview: 0.00%
#  Rebeccamouth: 0.01%
#  Sellersville: 0.00%
#  Lake Marthaside: 0.00%
#  Nguyenbury: 0.00%
#  East Elizabeth: 0.02%
#  New Christown: 0.00%
#  Delacruzmouth: 0.00%
#  Brandishire: 0.00%
#  Hallland: 0.00%
#  Port Donald: 0.01%
#  Rosalesfurt: 0.00%
#  Rebekahside: 0.00%
#  New Lindsay: 0.01%
#  South Allisonfort: 0.00%
#  West Meghanville: 0.00%
#  Joshuaport: 0.01%
#  Dianehaven: 0.00%
#  Stonefurt: 0.00%
#  South Grace: 0.00%
#  South Rebeccaville: 0.00%
#  Torrestown: 0.01%
#  Brandonburgh: 0.00%
#  East Dylan: 0.01%
#  Lake Bradleyside: 0.00%
#  Richardborough: 0.01%
#  Ericksonburgh: 0.00%
#  North Henrystad: 0.00%
#  South Brandi: 0.01%
#  West Patrickton: 0.00%
#  Cooperport: 0.01%
#  Davisborough: 0.01%
#  Ramosville: 0.01%
#  South Jenniferstad: 0.00%
#  West Zacharymouth: 0.00%
#  New Sandra: 0.01%
#  Jacksontown: 0.01%
#  North Patriciafort: 0.00%
#  Evansfort: 0.01%
#  Port Stacyfurt: 0.00%
#  Donnaburgh: 0.01%
#  Emilyborough: 0.01%
#  New Dennis: 0.01%
#  Bensonchester: 0.00%
#  Marissafort: 0.00%
#  West Tina: 0.01%
#  Port Taramouth: 0.00%
#  Brianton: 0.01%
#  Johnsonland: 0.02%
#  Lake Lauren: 0.01%
#  New Ryanton: 0.00%
#  East Heatherstad: 0.00%
#  Grahammouth: 0.00%
#  New Ricktown: 0.00%
#  West Phillipfort: 0.00%
#  West Justinbury: 0.00%
#  West Amanda: 0.03%
#  New Brittanytown: 0.00%
#  Matthewton: 0.01%
#  Fernandoport: 0.00%
#  Beverlyland: 0.00%
#  Adammouth: 0.01%
#  South Judy: 0.00%
#  West John: 0.05%
#  North Jenniferberg: 0.00%
#  Lake Susan: 0.02%
#  Leemouth: 0.02%
#  Jasonberg: 0.01%
#  Mikeshire: 0.00%
#  North Gerald: 0.01%
#  Smallside: 0.00%
#  Hurleychester: 0.00%
#  New Rachelborough: 0.00%
#  Priceton: 0.00%
#  Hallside: 0.01%
#  New Brittanyland: 0.00%
#  West Hayden: 0.00%
#  Vazquezborough: 0.00%
#  Spencerfurt: 0.00%
#  Ritterfort: 0.00%
#  Simonmouth: 0.00%
#  Ericville: 0.01%
#  Maybury: 0.00%
#  West Victoria: 0.01%
#  Whiteview: 0.01%
#  Edwinland: 0.00%
#  North Carlastad: 0.00%
#  North Robertfurt: 0.01%
#  Marcuschester: 0.00%
#  Rebeccaside: 0.01%
#  North Jeffreyfurt: 0.00%
#  Marytown: 0.01%
#  Deanstad: 0.01%
#  Heatherview: 0.01%
#  Williamsmouth: 0.04%
#  North Nathan: 0.01%
#  New Mauricestad: 0.00%
#  Wagnertown: 0.00%
#  West Shaun: 0.00%
#  Spencerstad: 0.00%
#  Kirstenport: 0.00%
#  Mooreland: 0.01%
#  North Theodore: 0.00%
#  Evanfurt: 0.00%
#  Carlosburgh: 0.00%
#  South Miguel: 0.00%
#  Port Andrea: 0.01%
#  Christopherport: 0.02%
#  Jacksonborough: 0.01%
#  Schneiderberg: 0.00%
#  Kingfort: 0.00%
#  West Josemouth: 0.00%
#  West Curtis: 0.00%
#  Mendezstad: 0.00%
#  Blackwellville: 0.00%
#  Derrickburgh: 0.00%
#  Herrerafurt: 0.00%
#  Vernonfurt: 0.00%
#  Kevinville: 0.01%
#  Gainesburgh: 0.00%
#  Tamarashire: 0.00%
#  North Wendy: 0.01%
#  Mendezmouth: 0.01%
#  Meghanshire: 0.00%
#  Lopezview: 0.00%
#  Herreraberg: 0.00%
#  Murphybury: 0.00%
#  East Jacob: 0.01%
#  Lake John: 0.06%
#  Wendyberg: 0.00%
#  Port Alyssatown: 0.00%
#  Jimenezport: 0.00%
#  Kelleyhaven: 0.00%
#  New Carriefurt: 0.00%
#  South Megantown: 0.00%
#  Fieldshaven: 0.00%
#  Kingchester: 0.01%
#  Riceton: 0.00%
#  Johnview: 0.02%
#  Whitneyburgh: 0.00%
#  East Susan: 0.02%
#  Butlerfurt: 0.00%
#  Johnsontown: 0.02%
#  Hannahland: 0.00%
#  Amberstad: 0.00%
#  North Tannerton: 0.00%
#  Mckinneyton: 0.00%
#  New Benjamin: 0.01%
#  Jacobsmouth: 0.00%
#  West Cliffordside: 0.00%
#  Vargasland: 0.00%
#  Lewismouth: 0.01%
#  Shawstad: 0.00%
#  New Edward: 0.02%
#  Port Toddfurt: 0.00%
#  South Mason: 0.00%
#  Wilsonburgh: 0.01%
#  Caseyville: 0.00%
#  Valenzuelaland: 0.00%
#  East Michelle: 0.02%
#  Dylanport: 0.00%
#  Emilyton: 0.01%
#  Kathytown: 0.00%
#  Farrellburgh: 0.00%
#  North Charlotteside: 0.00%
#  Riddlemouth: 0.00%
#  Hudsonfurt: 0.00%
#  West Christineview: 0.00%
#  Campbellview: 0.01%
#  North Jenniferview: 0.01%
#  New Shellybury: 0.00%
#  Davistown: 0.01%
#  Markbury: 0.01%
#  West Kathleen: 0.01%
#  New Laurabury: 0.00%
#  Lake Jamesstad: 0.01%
#  Danielleshire: 0.00%
#  Port Craigbury: 0.00%
#  Kathyshire: 0.00%
#  North Jasonstad: 0.00%
#  Bridgeston: 0.00%
#  New Jessicafort: 0.00%
#  Port Brendan: 0.00%
#  Port Nicoleburgh: 0.00%
#  North Karenmouth: 0.01%
#  Robbinsburgh: 0.00%
#  Washingtonborough: 0.00%
#  East Tyronemouth: 0.00%
#  Codybury: 0.00%
#  North Natalieborough: 0.00%
#  Rowlandside: 0.00%
#  Wrighthaven: 0.01%
#  Danielchester: 0.01%
#  Lake Amyfurt: 0.00%
#  Amyfort: 0.01%
#  Timothyfort: 0.01%
#  Boonechester: 0.00%
#  Kaitlynmouth: 0.00%
#  North Lauratown: 0.01%
#  South Danafort: 0.00%
#  Whitneymouth: 0.00%
#  Lake Tammy: 0.01%
#  Vargashaven: 0.00%
#  Tatemouth: 0.00%
#  West Christopherberg: 0.00%
#  East Claudia: 0.00%
#  Lake Monicaberg: 0.00%
#  Mistyberg: 0.00%
#  Snowfurt: 0.00%
#  Anthonyton: 0.01%
#  Darinville: 0.00%
#  New Normamouth: 0.00%
#  North Jessica: 0.03%
#  Josechester: 0.00%
#  Reneeshire: 0.00%
#  New Joyceburgh: 0.00%
#  Stephaniemouth: 0.03%
#  Danielstad: 0.01%
#  Ericton: 0.01%
#  New Andrewland: 0.00%
#  Brownburgh: 0.02%
#  Williamsville: 0.03%
#  Lake Karenberg: 0.00%
#  Erikshire: 0.00%
#  South Lisaland: 0.00%
#  Joseview: 0.01%
#  North Annaview: 0.00%
#  New Jamesborough: 0.00%
#  Francestown: 0.00%
#  New Paulborough: 0.00%
#  Ronaldborough: 0.00%
#  East John: 0.05%
#  South Shelley: 0.00%
#  North Victor: 0.00%
#  West Bryan: 0.01%
#  Lake Rachel: 0.02%
#  Lake Yvetteburgh: 0.00%
#  East Bethport: 0.00%
#  New Tasha: 0.00%
#  East Jeffrey: 0.02%
#  Travisside: 0.00%
#  Port William: 0.04%
#  North Johnbury: 0.00%
#  Andersonchester: 0.01%
#  North Jamesmouth: 0.01%
#  South Robert: 0.05%
#  Lake Morganville: 0.00%
#  Heatherhaven: 0.01%
#  Katelynside: 0.00%
#  New Mindyview: 0.00%
#  Ballardview: 0.00%
#  Taylorbury: 0.01%
#  South Keithland: 0.00%
#  Samuelmouth: 0.01%
#  South Chad: 0.01%
#  Josephville: 0.01%
#  Lake Johnborough: 0.01%
#  East Danielleberg: 0.00%
#  Port Lisa: 0.04%
#  Donnatown: 0.01%
#  Gardnerton: 0.00%
#  Jasonbury: 0.01%
#  South Jacobfort: 0.00%
#  Davidtown: 0.03%
#  West Daniellefort: 0.00%
#  Hughesborough: 0.00%
#  West Margaret: 0.02%
#  West Kevin: 0.03%
#  Jessicafort: 0.02%
#  Deniseport: 0.00%
#  New Luistown: 0.00%
#  West Vincentberg: 0.00%
#  West Paulmouth: 0.01%
#  East Kelly: 0.01%
#  Pruittton: 0.00%
#  Sarahshire: 0.01%
#  Port Melissastad: 0.01%
#  North Martin: 0.01%
#  Lake Williamshire: 0.00%
#  Wadebury: 0.00%
#  Matthewmouth: 0.03%
#  East Christineview: 0.00%
#  Ramoston: 0.01%
#  East Stephanietown: 0.00%
#  South Noahfort: 0.00%
#  New Dustin: 0.01%
#  North Brenda: 0.02%
#  South Evan: 0.00%
#  Lake Jacqueline: 0.01%
#  West Taylorborough: 0.00%
#  Ayershaven: 0.00%
#  West Brendaport: 0.00%
#  Mclaughlinchester: 0.00%
#  North Eric: 0.03%
#  Wilcoxland: 0.00%
#  Kingland: 0.01%
#  New Johnmouth: 0.01%
#  Christianton: 0.00%
#  New Jillianville: 0.00%
#  North Toddmouth: 0.00%
#  Hutchinsonfort: 0.00%
#  Nicholashaven: 0.01%
#  Randychester: 0.00%
#  West Jeff: 0.00%
#  West Bonniemouth: 0.00%
#  Sergioville: 0.00%
#  Port Toddside: 0.00%
#  Robinberg: 0.00%
#  West Michael: 0.08%
#  West Brandonmouth: 0.00%
#  Jamestown: 0.03%
#  Stoutfort: 0.00%
#  Lake Jennifermouth: 0.01%
#  Kimberlymouth: 0.02%
#  West Henrybury: 0.00%
#  Taramouth: 0.01%
#  Port Brenda: 0.01%
#  Ryanport: 0.01%
#  Kellershire: 0.00%
#  South Carlabury: 0.00%
#  Port Manuelhaven: 0.00%
#  Jasonstad: 0.01%
#  Carlstad: 0.00%
#  Coffeystad: 0.00%
#  Weaverhaven: 0.00%
#  Veronicastad: 0.00%
#  West Stephanie: 0.03%
#  Lisabury: 0.01%
#  Port Katherine: 0.01%
#  Ayersside: 0.00%
#  Lake Joyceport: 0.00%
#  Sanderston: 0.00%
#  North Darrylchester: 0.00%
#  Lake Derek: 0.01%
#  Knoxburgh: 0.00%
#  West Brittany: 0.01%
#  East Megan: 0.02%
#  Tiffanyville: 0.01%
#  Dianastad: 0.00%
#  Port Carlbury: 0.00%
#  West Michaelburgh: 0.00%
#  South Adrian: 0.00%
#  Knighthaven: 0.00%
#  West Joseph: 0.03%
#  South Anita: 0.01%
#  Ramosland: 0.00%
#  Lake Alexandra: 0.01%
#  East Jasonfort: 0.00%
#  West Jonathan: 0.01%
#  West Melanieview: 0.00%
#  Farrellberg: 0.00%
#  Sweeneyshire: 0.00%
#  Davischester: 0.01%
#  Brandyfort: 0.00%
#  Mariemouth: 0.00%
#  North Yvonne: 0.00%
#  Bakerborough: 0.01%
#  Trantown: 0.00%
#  Taylormouth: 0.01%
#  South Yolandachester: 0.00%
#  Port Lindsey: 0.01%
#  East Shaneview: 0.00%
#  Howardchester: 0.01%
#  Dunnmouth: 0.01%
#  West Williamhaven: 0.01%
#  Rachelstad: 0.01%
#  Jeffreyfurt: 0.01%
#  Hansenstad: 0.00%
#  North Wendyhaven: 0.00%
#  Jacobhaven: 0.01%
#  Brandonchester: 0.01%
#  Christyfurt: 0.00%
#  Rodriguezhaven: 0.01%
#  Erinland: 0.01%
#  Ruizton: 0.00%
#  Browningview: 0.00%
#  Smithport: 0.03%
#  Haydenton: 0.00%
#  Dianatown: 0.00%
#  Grahamberg: 0.00%
#  Murphyberg: 0.00%
#  Williamsshire: 0.02%
#  Fergusonville: 0.00%
#  New Bethanyfurt: 0.00%
#  Michaelview: 0.03%
#  East David: 0.06%
#  West Alyssa: 0.01%
#  Whiteshire: 0.01%
#  New Jennyside: 0.00%
#  Lake Samanthaville: 0.00%
#  Melissahaven: 0.01%
#  New Kimberly: 0.03%
#  Lake Jeremyland: 0.00%
#  Port Andrew: 0.03%
#  Meyermouth: 0.00%
#  North Aliciafort: 0.00%
#  South Pedrohaven: 0.00%
#  Lake Michaelview: 0.00%
#  West Eric: 0.03%
#  South Beverlyside: 0.00%
#  Lake Stephanieborough: 0.00%
#  East Emmafurt: 0.00%
#  New Elizabeth: 0.03%
#  Heathermouth: 0.02%
#  South Kathy: 0.00%
#  Williamton: 0.01%
#  New Deborah: 0.01%
#  South Chris: 0.00%
#  North Alicia: 0.01%
#  Alexbury: 0.00%
#  Williamburgh: 0.01%
#  East Monique: 0.01%
#  Billytown: 0.00%
#  New Traci: 0.00%
#  Castrofort: 0.00%
#  New Stevemouth: 0.00%
#  South Christina: 0.02%
#  East Zachary: 0.01%
#  Scotthaven: 0.01%
#  New Gabriel: 0.00%
#  East Anna: 0.01%
#  North Victoriafurt: 0.00%
#  Lake Juan: 0.01%
#  Hillberg: 0.00%
#  Lake Angela: 0.03%
#  Port Lawrencebury: 0.00%
#  Landryland: 0.00%
#  North Kylemouth: 0.00%
#  North Susan: 0.02%
#  Port Thomastown: 0.00%
#  Jonesfort: 0.02%
#  Jessicaborough: 0.01%
#  Port Kristin: 0.00%
#  Chavezhaven: 0.00%
#  Mariaberg: 0.01%
#  Freemanland: 0.00%
#  Port Mitchellmouth: 0.00%
#  Jimbury: 0.00%
#  New Morganbury: 0.00%
#  Shannonberg: 0.00%
#  Thomashaven: 0.01%
#  Port Dawnmouth: 0.00%
#  Lake Angelaville: 0.00%
#  Lake Tiffanytown: 0.00%
#  Lake Erika: 0.01%
#  West Jefferyfort: 0.00%
#  Rosarioland: 0.00%
#  Lake Earlhaven: 0.00%
#  South Heathertown: 0.00%
#  Kaiserhaven: 0.00%
#  East Charles: 0.02%
#  Port Alan: 0.01%
#  Holtstad: 0.00%
#  Lake April: 0.01%
#  Lake Davidside: 0.00%
#  Feliciaburgh: 0.00%
#  Walkerville: 0.00%
#  South Austin: 0.01%
#  Lake Robert: 0.05%
#  Roberthaven: 0.02%
#  Dianetown: 0.00%
#  Buckberg: 0.00%
#  Castroport: 0.00%
#  Sawyerfurt: 0.00%
#  Josephfurt: 0.01%
#  East Samanthaland: 0.00%
#  Hollyville: 0.00%
#  Longfurt: 0.00%
#  East Andrewchester: 0.00%
#  East Ashley: 0.03%
#  West Carlosville: 0.00%
#  Danielleland: 0.00%
#  Pamelashire: 0.00%
#  Smithfurt: 0.04%
#  Jodichester: 0.00%
#  Lake Matthewfort: 0.00%
#  Williamsburgh: 0.02%
#  Pamelaberg: 0.01%
#  New Raymondchester: 0.00%
#  Kevinmouth: 0.02%
#  Moniquefurt: 0.00%
#  Griffinberg: 0.00%
#  Anthonyfurt: 0.01%
#  Lake Zacharyfort: 0.00%
#  Bartonfort: 0.00%
#  North Jamesbury: 0.00%
#  Ashleyview: 0.02%
#  East Rebeccachester: 0.00%
#  Harrisonmouth: 0.00%
#  Raymouth: 0.01%
#  Nguyenfurt: 0.01%
#  Jeremyshire: 0.01%
#  Davidport: 0.02%
#  North Alisha: 0.00%
#  South Joseph: 0.03%
#  Jonathanside: 0.00%
#  Whitemouth: 0.02%
#  Hillport: 0.01%
#  Jacksonbury: 0.01%
#  Jessicaville: 0.02%
#  Grantborough: 0.00%
#  Adrianville: 0.00%
#  New Garyton: 0.00%
#  South Ryantown: 0.01%
#  East Matthew: 0.03%
#  West Laura: 0.02%
#  North Deborah: 0.02%
#  Lake Malloryborough: 0.00%
#  Watsonberg: 0.00%
#  Lake Gregoryport: 0.00%
#  North Kennethmouth: 0.00%
#  Kingville: 0.01%
#  Gallowayside: 0.00%
#  Sheltonhaven: 0.00%
#  Lake Gary: 0.01%
#  Port Lauraview: 0.00%
#  New Lindsey: 0.01%
#  Hillhaven: 0.00%
#  Burnsland: 0.00%
#  Lake Bradley: 0.01%
#  West Sarachester: 0.00%
#  Lake David: 0.06%
#  New Jefferyshire: 0.00%
#  Browninghaven: 0.00%
#  Carolinemouth: 0.00%
#  Karinaville: 0.00%
#  Lake Christopherstad: 0.00%
#  Fisherfurt: 0.00%
#  Jessicaview: 0.01%
#  Danielleport: 0.01%
#  East Jennifer: 0.06%
#  Staffordville: 0.00%
#  New Regina: 0.01%
#  Robertsonmouth: 0.01%
#  North Christychester: 0.00%
#  Lake Christineview: 0.00%
#  Port Sarahview: 0.00%
#  Port Williamport: 0.01%
#  Mitchellborough: 0.02%
#  Leetown: 0.01%
#  Nicoleton: 0.01%
#  West Jean: 0.00%
#  Kathybury: 0.00%
#  South Rebecca: 0.02%
#  Cartermouth: 0.01%
#  North Fernando: 0.00%
#  South Kevin: 0.03%
#  Michaelchester: 0.04%
#  Lake Ricky: 0.00%
#  Elizabethborough: 0.01%
#  Port Brianland: 0.00%
#  East Stephanie: 0.02%
#  Aaronfort: 0.01%
#  Adrianaland: 0.00%
#  Ericaview: 0.00%
#  North Cliffordstad: 0.00%
#  Tanyafurt: 0.00%
#  Stevensonside: 0.00%
#  Lake Cathy: 0.01%
#  Mcfarlandchester: 0.00%
#  South Brentville: 0.00%
#  West Catherineberg: 0.00%
#  East Amy: 0.02%
#  Port Ryanshire: 0.00%
#  Hillchester: 0.01%
#  Berryview: 0.00%
#  Tylerton: 0.00%
#  South Daleberg: 0.00%
#  Joshuaberg: 0.01%
#  Port Marc: 0.00%
#  North Vanessa: 0.01%
#  Ericmouth: 0.01%
#  North Adrianchester: 0.00%
#  New Madison: 0.01%
#  Leeland: 0.01%
#  Hodgesview: 0.00%
#  West Darrenview: 0.00%
#  West Devin: 0.00%
#  South Robinmouth: 0.00%
#  New Willietown: 0.00%
#  Murphytown: 0.00%
#  Garciafort: 0.01%
#  Kellyberg: 0.01%
#  Christophertown: 0.02%
#  Derekport: 0.01%
#  Port Linda: 0.01%
#  New Lucas: 0.00%
#  West Heidi: 0.01%
#  Camposland: 0.00%
#  Huntfort: 0.00%
#  West Christina: 0.02%
#  Lake James: 0.05%
#  Lewishaven: 0.00%
#  West Michaelview: 0.00%
#  Port Peggy: 0.00%
#  West Brittney: 0.00%
#  Port Patricia: 0.02%
#  West Adam: 0.01%
#  Lake Antonio: 0.00%
#  Sarahport: 0.01%
#  New Judithfort: 0.00%
#  Lake Benjaminstad: 0.00%
#  North Yvonneberg: 0.00%
#  Phillipsview: 0.00%
#  East Justinview: 0.00%
#  New Tylertown: 0.00%
#  Suttonmouth: 0.00%
#  New Jasonland: 0.00%
#  Braunburgh: 0.00%
#  Krystalmouth: 0.00%
#  New Anthonyland: 0.00%
#  Simonton: 0.00%
#  West Davidborough: 0.01%
#  New Timothyshire: 0.00%
#  Johnburgh: 0.02%
#  Port Phillip: 0.01%
#  North Tannerside: 0.00%
#  Johnsonshire: 0.03%
#  Lake Krystalville: 0.00%
#  Ramosfort: 0.00%
#  Brittanytown: 0.01%
#  Marissatown: 0.00%
#  Jamesview: 0.01%
#  North Mary: 0.03%
#  Lake Christopher: 0.05%
#  Chasechester: 0.00%
#  East Thomasfort: 0.00%
#  Reedborough: 0.00%
#  East Jason: 0.03%
#  East Kimberlyhaven: 0.00%
#  Lauraland: 0.01%
#  Angelabury: 0.01%
#  Rossborough: 0.00%
#  East Jessicamouth: 0.01%
#  Nathanfort: 0.00%
#  West Alex: 0.01%
#  North Denise: 0.01%
#  South Theodore: 0.00%
#  North Kellyburgh: 0.00%
#  West Raychester: 0.00%
#  Murphymouth: 0.01%
#  West Ricardofurt: 0.00%
#  Perryfurt: 0.00%
#  Chloechester: 0.00%
#  Port Kimberlyton: 0.00%
#  Riddleshire: 0.00%
#  New Peterland: 0.00%
#  North Tanya: 0.01%
#  Port Tonyaberg: 0.00%
#  Port Jennifer: 0.06%
#  Vangshire: 0.00%
#  Lake Ana: 0.00%
#  North Kristopher: 0.01%
#  West Jasonshire: 0.00%
#  Danielsmouth: 0.00%
#  North Regina: 0.01%
#  East Conniechester: 0.00%
#  Rodriguezberg: 0.01%
#  Brianborough: 0.01%
#  South Joshua: 0.03%
#  North Miashire: 0.00%
#  East Anthonychester: 0.00%
#  Tracyshire: 0.01%
#  Lake Anthonychester: 0.00%
#  East Troy: 0.01%
#  New Leslieburgh: 0.00%
#  New Nicholas: 0.02%
#  Mcdonaldside: 0.01%
#  Nancyfurt: 0.00%
#  Port Karenville: 0.00%
#  Harpermouth: 0.00%
#  Andrewsburgh: 0.00%
#  New Matthewmouth: 0.00%
#  Jeffreyville: 0.01%
#  Griffinstad: 0.00%
#  East Deanna: 0.00%
#  Alyssaborough: 0.00%
#  Lake Julie: 0.01%
#  Kathleenfurt: 0.01%
#  East Nancy: 0.01%
#  Adrianachester: 0.00%
#  Josephview: 0.01%
#  Amberville: 0.00%
#  East Brooke: 0.01%
#  New Lisafurt: 0.00%
#  New Hayleymouth: 0.00%
#  East Ronaldberg: 0.00%
#  West Jordan: 0.00%
#  East Renee: 0.01%
#  Lake Jacobside: 0.00%
#  Mccannstad: 0.00%
#  East Adamchester: 0.00%
#  Jamesborough: 0.02%
#  Terriland: 0.00%
#  New Shauntown: 0.00%
#  New Shaneview: 0.00%
#  Watkinsmouth: 0.01%
#  North Desireeberg: 0.00%
#  Port Eriktown: 0.00%
#  Lopezbury: 0.00%
#  New Danielton: 0.00%
#  West Brittanyville: 0.00%
#  North Vickieburgh: 0.00%
#  Suzannebury: 0.00%
#  Zacharyfort: 0.01%
#  Tamarafurt: 0.00%
#  Brianhaven: 0.01%
#  Lake Brandyton: 0.00%
#  Lake Brandonchester: 0.00%
#  South Richard: 0.03%
#  East Robertport: 0.01%
#  Johnbury: 0.02%
#  Lake Raymondtown: 0.00%
#  Bennetttown: 0.01%
#  South Derek: 0.01%
#  Angelaburgh: 0.01%
#  North Amanda: 0.03%
#  Erinview: 0.01%
#  East Robertton: 0.00%
#  Johnsonborough: 0.02%
#  Port Sonyaview: 0.00%
#  Bensonbury: 0.00%
#  Josephton: 0.02%
#  Gabrielland: 0.00%
#  Port Eddie: 0.00%
#  East Jeffreyshire: 0.00%
#  Gibbsstad: 0.00%
#  Ryanmouth: 0.01%
#  Lake Tanner: 0.00%
#  Maryburgh: 0.01%
#  North Katherinechester: 0.00%
#  Stephaniestad: 0.01%
#  Kirbyview: 0.00%
#  Sotoland: 0.00%
#  Cindytown: 0.01%
#  South Michelle: 0.03%
#  Muellerfurt: 0.00%
#  North Williamchester: 0.01%
#  Thorntonstad: 0.00%
#  Port Markbury: 0.00%
#  Lake Kevinmouth: 0.00%
#  Jenniferport: 0.02%
#  Harmonmouth: 0.00%
#  Aguilarton: 0.00%
#  West Sarahstad: 0.00%
#  Obrienchester: 0.00%
#  New Samuel: 0.01%
#  Port Mary: 0.02%
#  Claytonville: 0.00%
#  West Benjamin: 0.02%
#  New Joshuachester: 0.00%
#  Johnstonshire: 0.00%
#  Jessicaburgh: 0.01%
#  Harrisfurt: 0.01%
#  East Matthewville: 0.00%
#  New Jessica: 0.04%
#  Staceyside: 0.00%
#  Lake Allison: 0.01%
#  Shawton: 0.01%
#  Edwardsburgh: 0.00%
#  Collinsville: 0.01%
#  North Joshua: 0.03%
#  Andrewville: 0.01%
#  Fieldschester: 0.00%
#  Pottston: 0.00%
#  Patriciashire: 0.01%
#  Lake Donnachester: 0.00%
#  North Michellemouth: 0.01%
#  West Jefferychester: 0.00%
#  North Angela: 0.03%
#  Daniellefurt: 0.01%
#  Schmidtchester: 0.01%
#  Phyllisport: 0.00%
#  Abbottburgh: 0.00%
#  Jonborough: 0.00%
#  Rojashaven: 0.00%
#  South Samuelberg: 0.00%
#  New Anthony: 0.03%
#  Wernerfort: 0.00%
#  East Timothyton: 0.00%
#  Proctormouth: 0.00%
#  West Bethanyview: 0.00%
#  Manningport: 0.00%
#  New Herbertmouth: 0.00%
#  North Frank: 0.01%
#  North Katherineside: 0.00%
#  East Kristin: 0.01%
#  Lake Troy: 0.00%
#  Lake Brittanymouth: 0.00%
#  North Samuelport: 0.00%
#  Bestmouth: 0.00%
#  Fordfurt: 0.00%
#  Port Tiffanyburgh: 0.00%
#  Larryshire: 0.00%
#  Danielburgh: 0.02%
#  East Luisport: 0.00%
#  North Jenniferland: 0.00%
#  Port Jenniferfort: 0.00%
#  Port Jerry: 0.01%
#  Marymouth: 0.02%
#  Lake Melinda: 0.00%
#  Shannonchester: 0.00%
#  East Melissaville: 0.00%
#  Raymondton: 0.01%
#  Davidview: 0.03%
#  East Tiffanychester: 0.00%
#  Floydville: 0.00%
#  Jenniferville: 0.02%
#  North Kathleenmouth: 0.00%
#  West Mike: 0.01%
#  Lewiston: 0.01%
#  Kennethville: 0.00%
#  Lake Cody: 0.01%
#  Ariasland: 0.00%
#  Hermanstad: 0.00%
#  Malikton: 0.00%
#  South Lisaport: 0.00%
#  East Laurie: 0.01%
#  Reedmouth: 0.01%
#  North Michaelbury: 0.00%
#  Lake Penny: 0.00%
#  Terryville: 0.00%
#  Kennethstad: 0.00%
#  Michaelmouth: 0.07%
#  Lake Robinton: 0.00%
#  Danielfort: 0.02%
#  Harrisburgh: 0.01%
#  Traviston: 0.00%
#  East Joseph: 0.04%
#  East Michaelside: 0.01%
#  Port Emily: 0.01%
#  Robertsonborough: 0.00%
#  Harrisside: 0.00%
#  Virginiashire: 0.00%
#  Landryport: 0.00%
#  South Danielle: 0.01%
#  North Michelle: 0.03%
#  Michelleland: 0.01%
#  South Richardland: 0.00%
#  West Jamesland: 0.00%
#  Anntown: 0.00%
#  North Veronicaview: 0.00%
#  Pattersonberg: 0.00%
#  New Tanya: 0.00%
#  Robertsonstad: 0.01%
#  Chungstad: 0.00%
#  New Suzannefort: 0.00%
#  South Jeffery: 0.01%
#  Judithport: 0.00%
#  Ramirezshire: 0.01%
#  New Jasmineshire: 0.00%
#  Lake Andreachester: 0.00%
#  Robertfurt: 0.02%
#  North Amandaside: 0.01%
#  Delgadomouth: 0.01%
#  South Kathyside: 0.00%
#  New Michaelchester: 0.01%
#  Maryview: 0.01%
#  West Leah: 0.00%
#  West Christine: 0.01%
#  Lake Jeremy: 0.01%
#  Julieshire: 0.00%
#  East Benjamin: 0.01%
#  Sarahhaven: 0.01%
#  Johnberg: 0.02%
#  Tannerbury: 0.00%
#  Cordovahaven: 0.00%
#  Brownborough: 0.01%
#  Port Nicole: 0.02%
#  Jessicahaven: 0.01%
#  New Veronicaton: 0.00%
#  East Martinfort: 0.00%
#  Lake Amandahaven: 0.00%
#  Gonzaleschester: 0.00%
#  New Colleenmouth: 0.00%
#  New Melissa: 0.04%
#  Warrenmouth: 0.00%
#  Williamview: 0.01%
#  Lake Jamieborough: 0.00%
#  South Josephville: 0.00%
#  Roseport: 0.00%
#  Hansenville: 0.00%
#  Diazshire: 0.00%
#  Nelsonberg: 0.00%
#  Port Carla: 0.00%
#  East Justinton: 0.00%
#  South Courtneyland: 0.00%
#  South Victoriahaven: 0.00%
#  New Raymondshire: 0.00%
#  New Jamesmouth: 0.00%
#  Lake Jaredfort: 0.00%
#  Henryburgh: 0.01%
#  Heatherville: 0.01%
#  South Tiffany: 0.01%
#  Ronaldchester: 0.00%
#  Erikaland: 0.00%
#  Yanghaven: 0.00%
#  Reeseside: 0.00%
#  West Lisa: 0.03%
#  South Kayla: 0.02%
#  East Thomas: 0.02%
#  West Melissaside: 0.00%
#  New Daisy: 0.00%
#  New April: 0.01%
#  North Patrick: 0.02%
#  Campbellmouth: 0.01%
#  Port Julian: 0.00%
#  South Annfurt: 0.00%
#  West Darius: 0.00%
#  North Angelabury: 0.00%
#  Marvinberg: 0.00%
#  Tinatown: 0.00%
#  Kelleyburgh: 0.00%
#  Port Kristinastad: 0.00%
#  North Glenburgh: 0.00%
#  West Danafurt: 0.00%
#  South Stephanie: 0.02%
#  Hallbury: 0.00%
#  Haynesville: 0.00%
#  Coreyville: 0.00%
#  Stevenborough: 0.01%
#  Grantburgh: 0.00%
#  North Jonathanberg: 0.00%
#  New Gregory: 0.01%
#  West Jared: 0.01%
#  New Phillip: 0.00%
#  Pinedachester: 0.01%
#  South Sarah: 0.02%
#  North Jeanne: 0.00%
#  Nathantown: 0.00%
#  Gonzalezport: 0.01%
#  Port Adamland: 0.00%
#  East Gloria: 0.00%
#  Hayleyberg: 0.00%
#  Lake Jamie: 0.01%
#  East Lindaburgh: 0.00%
#  West Erik: 0.00%
#  Ellisontown: 0.00%
#  North Jacobport: 0.00%
#  Stevenport: 0.01%
#  Edwardberg: 0.01%
#  Wendychester: 0.00%
#  West Nicholaston: 0.00%
#  Perkinsberg: 0.00%
#  Christopherland: 0.02%
#  Deleonborough: 0.00%
#  New Gary: 0.01%
#  Mariaborough: 0.00%
#  East Brenda: 0.01%
#  South Williammouth: 0.00%
#  Danieltown: 0.01%
#  Lake Laura: 0.02%
#  South Williamview: 0.00%
#  West Neil: 0.00%
#  Justinview: 0.01%
#  Ellisside: 0.00%
#  Port Maryside: 0.00%
#  South Josephside: 0.00%
#  North Travis: 0.01%
#  Lake Ashleybury: 0.00%
#  Lake Shelbytown: 0.00%
#  Crawfordshire: 0.00%
#  Sarahmouth: 0.03%
#  Port Ashley: 0.02%
#  Doylechester: 0.00%
#  New Kimfort: 0.00%
#  West William: 0.04%
#  Tonyamouth: 0.00%
#  East Gina: 0.01%
#  Amandaton: 0.01%
#  Port Guyside: 0.00%
#  Sloanland: 0.00%
#  Beltranhaven: 0.00%
#  Knightfort: 0.00%
#  New Nancytown: 0.00%
#  Port Danielbury: 0.00%
#  Hamiltonstad: 0.00%
#  Lozanostad: 0.00%
#  Rileyshire: 0.00%
#  Madisonside: 0.00%
#  East Cory: 0.01%
#  Lake Aliciaton: 0.00%
#  Karlside: 0.00%
#  Velezchester: 0.00%
#  South Matthew: 0.04%
#  North Alison: 0.00%
#  Christinemouth: 0.01%
#  Jamesville: 0.03%
#  West Charles: 0.02%
#  Alvarezside: 0.01%
#  Julianburgh: 0.00%
#  Lake Melaniemouth: 0.00%
#  Josephstad: 0.01%
#  South Kelly: 0.01%
#  Micheleside: 0.01%
#  Port David: 0.05%
#  Gabrielleside: 0.00%
#  Destinyton: 0.00%
#  Courtneyport: 0.00%
#  South Jessicastad: 0.00%
#  Morenotown: 0.00%
#  West Alfred: 0.00%
#  Sandrastad: 0.00%
#  Millerberg: 0.01%
#  New Susanmouth: 0.00%
#  Lindatown: 0.00%
#  East Manuelview: 0.00%
#  Markville: 0.01%
#  East Rebecca: 0.02%
#  West Pamela: 0.01%
#  Jordantown: 0.01%
#  Meganville: 0.01%
#  Saundersview: 0.00%
#  Baileyburgh: 0.00%
#  Traceyburgh: 0.00%
#  Farmerstad: 0.00%
#  South Cynthia: 0.01%
#  North Melanie: 0.01%
#  Bentontown: 0.00%
#  Foxtown: 0.00%
#  East Heatherfurt: 0.00%
#  East Georgeport: 0.00%
#  West Markberg: 0.00%
#  Ballmouth: 0.00%
#  Rachelport: 0.01%
#  Thompsontown: 0.01%
#  Port Ronald: 0.01%
#  East Amymouth: 0.00%
#  Flynnborough: 0.00%
#  Walkerburgh: 0.01%
#  Port Samuel: 0.01%
#  Thomasfort: 0.02%
#  Matthewsview: 0.00%
#  Payneville: 0.00%
#  Tylermouth: 0.01%
#  North Alan: 0.01%
#  New Angelabury: 0.00%
#  East Nicholas: 0.02%
#  Lindseystad: 0.00%
#  Rachaelberg: 0.00%
#  Bakerburgh: 0.01%
#  Davidborough: 0.02%
#  Perezfurt: 0.01%
#  West Davidshire: 0.00%
#  Port Gregoryport: 0.00%
#  Hughesville: 0.00%
#  West Jody: 0.00%
#  Port Kristinborough: 0.00%
#  Webbland: 0.00%
#  Jennytown: 0.00%
#  West Danielleside: 0.00%
#  Velasquezstad: 0.00%
#  Chadland: 0.00%
#  East Timothy: 0.02%
#  Justinton: 0.01%
#  West Tanya: 0.01%
#  East Brendatown: 0.00%
#  Jonesshire: 0.02%
#  Gonzalezside: 0.01%
#  Lisaside: 0.01%
#  Port Joshualand: 0.00%
#  New Amy: 0.03%
#  Reginachester: 0.00%
#  New David: 0.04%
#  Graystad: 0.00%
#  West Randyshire: 0.00%
#  Tinaberg: 0.01%
#  New Virginiachester: 0.00%
#  Warrenville: 0.00%
#  East Michaelbury: 0.00%
#  Maloneview: 0.00%
#  East Travis: 0.00%
#  New Chris: 0.00%
#  East Georgeville: 0.00%
#  Butlerberg: 0.00%
#  Jonathanview: 0.01%
#  Lake Nathanport: 0.00%
#  South Nichole: 0.00%
#  North Sallyshire: 0.00%
#  Boltonmouth: 0.00%
#  South Robertview: 0.01%
#  South Zachary: 0.01%
#  Rowechester: 0.00%
#  West Kellychester: 0.00%
#  Scottburgh: 0.02%
#  Leroyborough: 0.00%
#  North Davidland: 0.01%
#  New Vickiefort: 0.00%
#  New Jessicaland: 0.00%
#  Hodgemouth: 0.00%
#  Burnettshire: 0.00%
#  East Carl: 0.01%
#  Lake Heather: 0.02%
#  Salastown: 0.00%
#  Leeside: 0.01%
#  North Jacqueline: 0.01%
#  Kimville: 0.01%
#  West Derekside: 0.00%
#  West Matthewside: 0.01%
#  Port Heather: 0.02%
#  Mendozaburgh: 0.00%
#  Port Henry: 0.00%
#  West Georgehaven: 0.00%
#  Lake Daniel: 0.04%
#  South Christine: 0.01%
#  New Nathanielberg: 0.00%
#  South Rickybury: 0.00%
#  North Dylanport: 0.00%
#  New Shelly: 0.00%
#  Myersmouth: 0.01%
#  South Sandrabury: 0.00%
#  Sosastad: 0.00%
#  Port Johnville: 0.01%
#  Codyburgh: 0.01%
#  Port Diana: 0.00%
#  Port Stephanie: 0.02%
#  New Christophershire: 0.00%
#  Meganside: 0.01%
#  Evanshaven: 0.01%
#  Mathewsburgh: 0.00%
#  West Melanie: 0.01%
#  Lake Jo: 0.00%
#  Curtisfort: 0.00%
#  North Jamestown: 0.01%
#  Wintersbury: 0.00%
#  Stantontown: 0.00%
#  Lake Charles: 0.02%
#  South Lisa: 0.03%
#  Port Julia: 0.01%
#  Millerfurt: 0.01%
#  Brownhaven: 0.01%
#  Lake Michelle: 0.03%
#  Jeffreyport: 0.01%
#  Duncanmouth: 0.01%
#  Michaelton: 0.02%
#  Stephenland: 0.01%
#  Freemanborough: 0.00%
#  Shannonmouth: 0.01%
#  Martinside: 0.01%
#  Aaronfurt: 0.01%
#  Georgetown: 0.00%
#  North Ronaldview: 0.00%
#  Port Keithton: 0.00%
#  North Jennifer: 0.05%
#  Owenstown: 0.00%
#  New Walterton: 0.00%
#  Lake Margaret: 0.00%
#  Michaelborough: 0.03%
#  Lake Martinborough: 0.00%
#  Jessicastad: 0.01%
#  Jamieland: 0.00%
#  Port Michelleland: 0.00%
#  Josephshire: 0.01%
#  Smithview: 0.03%
#  Brettton: 0.00%
#  West Maria: 0.01%
#  Draketown: 0.00%
#  Guerrastad: 0.00%
#  Floydfurt: 0.00%
#  West Samanthaland: 0.00%
#  Briannachester: 0.00%
#  West Tylerborough: 0.00%
#  North Thomasborough: 0.00%
#  West Zachary: 0.01%
#  Ramirezbury: 0.01%
#  Jamesfort: 0.02%
#  Nicholefort: 0.00%
#  Dustinton: 0.00%
#  Jasmineborough: 0.00%
#  Port Edgar: 0.00%
#  Jacksonview: 0.01%
#  Christopherhaven: 0.02%
#  Halltown: 0.01%
#  Jerryfurt: 0.00%
#  Lake Connorburgh: 0.00%
#  West Matthew: 0.04%
#  Bakermouth: 0.01%
#  Romerochester: 0.00%
#  Tracyfort: 0.01%
#  Goodmanfurt: 0.00%
#  Leonardside: 0.00%
#  Davilaside: 0.00%
# ...
#  South Toddstad: 1
#  New Nancyborough: 1
#  Kanebury: 1
#  Cheyenneton: 1
#  Jasminechester: 1
#  Isaacmouth: 1
#  West Bethanyfurt: 1
#  Port Bernardton: 1
#  Port Alyssaport: 1
#  West Alexanderhaven: 1
#  North Madisonfort: 1
#  New Tylerburgh: 1
#  East Danielleview: 1
#  East Meagantown: 1
#  East Steve: 1
#  New Justinhaven: 1
#  East Caseyfurt: 1
#  Haasbury: 1
#  New Rebeccaview: 1
#  Robertamouth: 1
#  North Brenthaven: 1
#  New Karenville: 1
#  Kayleefurt: 1
#  Port Jonathanport: 1
#  West Meganshire: 1
#  Port Edwinhaven: 1
#  West Tracyhaven: 1
#  Haileyport: 1
#  East Annaborough: 1
#  Port Marialand: 1
#  East Royland: 1
#  Lake Robynborough: 1
#  Howellstad: 1
#  Bartonside: 1
#  Moniquebury: 1
#  Novakbury: 1
#  New Katherineland: 1
#  Jarvisfurt: 2
#  Willisfort: 2
#  Rhodestown: 1
#  North Mariah: 1
#  Herringland: 1
#  Beanland: 1
#  Lake Pamelahaven: 1
#  East Melindashire: 1
#  Blackwellport: 1
#  Port Dianafort: 1
#  West Marcburgh: 1
#  Hornmouth: 1
#  Lake Sharonborough: 1
#  Joyburgh: 1
#  New Zacharychester: 1
#  East Charlesland: 1
#  East Stephenshire: 1
#  West Troyburgh: 1
#  New Ashlee: 1
#  South Thomaschester: 1
#  Lake Brandonville: 1
#  East Markhaven: 1
#  Tateton: 1
#  West Jodyburgh: 1
#  Nicholsfort: 1
#  New Shelbyton: 1
#  Kurtfurt: 1
#  North Lucasland: 1
#  West Breannashire: 1
#  Sonyaville: 1
#  Port Toddtown: 1
#  New Dawnville: 2
#  South Reneechester: 1
#  Delgadofurt: 1
#  Evanmouth: 1
#  East Lindaside: 1
#  Branchmouth: 1
#  East Spencerstad: 1
#  North Karinaview: 1
#  East Cassandrahaven: 1
#  North Reneeton: 1
#  Lake Jimmyfort: 1
#  South Isabel: 1
#  Pruittside: 1
#  Mauricemouth: 1
#  South Erinhaven: 1
#  North Darrellbury: 1
#  Lake Shannonhaven: 1
#  North Elizabethland: 1
#  North Calvinburgh: 1
#  Hansonstad: 1
#  East Mariaberg: 1
#  Lake Jayview: 1
#  Port Dennisshire: 1
#  South Diamondmouth: 1
#  Port Madisonstad: 1
#  Barbaraberg: 1
#  South Ethanmouth: 1
#  Lake Bobbychester: 1
#  Lake Dakotaville: 1
#  South Alexandriaberg: 1
#  New Mariahfort: 1
#  Port Chrisborough: 1
#  Port Parkerburgh: 1
#  Port Rachelfort: 1
#  West Raymondburgh: 1
#  Singletonshire: 1
#  Port Amyside: 1
#  Lake Tarabury: 1
#  South Angelabury: 1
#  New Brandistad: 1
#  Port Bill: 1
#  Port Ginamouth: 1
#  Joechester: 1
#  West Anthonyville: 1
#  South Anaside: 1
#  Zhanghaven: 1
#  West Alejandroberg: 1
#  Lake Samuelfort: 1
#  Sheriville: 1
#  Alfredland: 1
#  Joanchester: 1
#  Lake Carolynbury: 1
#  North Joannville: 1
#  Port Warrenberg: 1
#  Melendezview: 1
#  North Nathanland: 1
#  Lake Kimshire: 1
#  South Tonyside: 1
#  New Sonia: 1
#  Zhangshire: 1
#  Hollowayhaven: 1
#  Port Dawnport: 1
#  East Kathrynview: 1
#  North Alanhaven: 1
#  North Gwendolynland: 1
#  Derrickfort: 1
#  East Seanfort: 1
#  South Josechester: 1
#  Welchton: 1
#  Villanuevaberg: 1
#  Stevenshaven: 1
#  Port Juanland: 1
#  Hendrixtown: 1
#  Colleenburgh: 1
#  North Kristenfurt: 1
#  North Frankmouth: 1
#  New Patrickchester: 1
#  New Dakotachester: 1
#  East Catherinetown: 1
#  Lake Willie: 1
#  New Wandashire: 1
#  North Katiehaven: 1
#  Port Virginiaside: 1
#  Bassmouth: 1
#  East Antoniotown: 1
#  Clarkeburgh: 1
#  South Wesleyburgh: 1
#  Miguelshire: 1
#  Port Phillipberg: 1
#  Lake Dawnview: 1
#  Fitzgeraldberg: 1
#  New Logan: 1
#  West Theresastad: 1
#  Walshberg: 1
#  Proctorberg: 1
#  Lake Garyport: 1
#  South Zacharyberg: 1
#  Calvinshire: 1
#  West Sandyport: 1
#  East Mariochester: 1
#  North Vernon: 1
#  West Kimfort: 1
#  North Ellen: 1
#  North Jacquelineton: 1
#  South Taylorburgh: 1
#  South Carmenport: 1
#  Joanstad: 1
#  South Frankbury: 1
#  Joanshire: 1
#  East Morganhaven: 1
#  East Allenside: 1
#  North Adamside: 1
#  Hopkinsville: 1
#  Guerraton: 1
#  New Allisonshire: 1
#  Deborahtown: 1
#  Lake Joyceview: 1
#  West Bethanyport: 1
#  Lake Glennland: 1
#  East Dylanberg: 1
#  South Howard: 1
#  Parkshaven: 1
#  Port Terryburgh: 1
#  West Brandonberg: 1
#  New Markton: 1
#  Harveyport: 1
#  Hunthaven: 1
#  South Dylanport: 1
#  Suttonhaven: 1
#  Joannaland: 1
#  Craneport: 1
#  New Jeremyland: 1
#  Genebury: 1
#  South Hannahtown: 1
#  New Jocelynborough: 1
#  North Christineshire: 1
#  Port Alisonborough: 1
#  Lake Veronicaland: 1
#  Port Morganberg: 1
#  Lawsonland: 1
#  New Rachelton: 1
#  Collierhaven: 1
#  Port Coreyland: 1
#  Lake Karenchester: 1
#  Stonebury: 1
#  Barnettport: 1
#  New Edwardstad: 1
#  East Destiny: 1
#  South Darlene: 1
#  Port Billystad: 1
#  West Belinda: 1
#  New Marthabury: 1
#  East Kyleport: 1
#  Port Williamland: 1
#  New Jakeshire: 1
#  North Meaganmouth: 1
#  South Sarashire: 1
#  South Catherineberg: 1
#  Oliviastad: 1
#  New Luisside: 1
#  North Stephanieport: 1
#  South Tylertown: 1
#  Carlaville: 1
#  West Vanessa: 1
#  Lake Erikside: 1
#  East Coryview: 1
#  North Micheleport: 1
#  Lake Billytown: 1
#  West Amberstad: 1
#  Hickmanstad: 1
#  Hartmanview: 1
#  New Kellyhaven: 1
#  Hectortown: 1
#  West Meganchester: 1
#  Lake Joville: 1
#  East Sethfurt: 1
#  Lake Cindychester: 1
#  Stoneland: 1
#  New Krystalton: 1
#  Port Gabrielchester: 1
#  New Tammyfurt: 1
#  Lake Deborahfurt: 1
#  New Markborough: 1
#  Lake Chrisview: 1
#  Port Sarafurt: 1
#  North Clarenceburgh: 1
#  South Calebton: 1
#  Trevorland: 1
#  East Bryanport: 1
#  Madisonberg: 1
#  Dunnside: 1
#  North Derektown: 1
#  New Alexanderfort: 1
#  Port Ashleytown: 1
#  Port Beverlyville: 1
#  Laceyfort: 1
#  Bowentown: 1
#  East Fernandostad: 1
#  Spearsborough: 1
#  North Crystalbury: 1
#  East Larryville: 1
#  Davidsonfurt: 1
#  Cookburgh: 2
#  Rickyport: 1
#  South Jeremyshire: 1
#  Haneyton: 1
#  Glassburgh: 1
#  South Dianemouth: 1
#  Port Kimfurt: 1
#  Lake Juantown: 1
#  Lake Vernon: 1
#  New Melinda: 1
#  Fuentesview: 1
#  Perkinsport: 1
#  Port Rebekah: 1
#  New Stephaniebury: 1
#  Port Brianamouth: 1
#  West Ianbury: 1
#  North Jonathonport: 1
#  North Kathrynland: 1
#  East Darrylchester: 1
#  Port Rubentown: 1
#  Rogersstad: 1
#  Cathyside: 1
#  Darrylchester: 1
#  South Janetfurt: 1
#  Ramosborough: 1
#  Lutzton: 1
#  South Kelseyfurt: 1
#  East Markburgh: 1
#  Port Jimtown: 1
#  Mollychester: 1
#  Micheleshire: 1
#  Lake Deborahchester: 1
#  New Pammouth: 1
#  Lake Natasha: 1
#  Maureenfurt: 1
#  Gregport: 1
#  North Sheryl: 1
#  Port Jacksonberg: 1
#  East Pennyville: 1
#  East Jessemouth: 1
#  Port Coryport: 1
#  New Franciston: 1
#  New Jaredbury: 1
#  West Luishaven: 1
#  North Jacktown: 1
#  South Joelland: 1
#  Schmittchester: 1
#  North Jefferymouth: 1
#  South Nicholasville: 1
#  West Marcuston: 1
#  North Henrymouth: 1
#  South Alisonport: 1
#  North Cynthiaton: 1
#  North Kennethburgh: 1
#  New Lynnshire: 1
#  New Johnburgh: 1
#  Foleyfurt: 1
#  North Samanthafurt: 1
#  New Juliastad: 1
#  Lake Robertstad: 1
#  East Lawrencebury: 1
#  Ronniefurt: 1
#  Port Gabriellefort: 1
#  South Cynthiaton: 1
#  South Eddieview: 1
#  East Tracyborough: 1
#  South Alexanderland: 1
#  West Austinborough: 1
#  Sethview: 1
#  Villanuevaburgh: 1
#  New Lauriebury: 1
#  West Kristinamouth: 1
#  North Oscarview: 1
#  Newtontown: 1
#  Port Teresahaven: 1
#  South Nathanborough: 1
#  New Aliciachester: 1
#  Tamarastad: 1
#  Lake Williamland: 2
#  New Josephberg: 1
#  East Alexismouth: 1
#  New Brittanyton: 1
#  West Laceyborough: 1
#  West Elijah: 1
#  Fischershire: 1
#  Sanfordborough: 1
#  Maddoxmouth: 1
#  Port Bryanmouth: 1
#  South Rickyfort: 1
#  Lake Tracytown: 1
#  Port Chelseaberg: 1
#  Joeshire: 1
#  Sierraburgh: 1
#  Lake Deborahview: 1
#  North Curtisshire: 1
#  North Markview: 1
#  North Tonyville: 1
#  Wallstown: 1
#  Port Peterberg: 1
#  Dixonborough: 1
#  Cainfort: 1
#  Villegasside: 1
#  South Reginastad: 1
#  Deckerborough: 1
#  Lake Brenthaven: 1
#  Joannaville: 1
#  Erikaberg: 1
#  East Brentbury: 1
#  South Coreyhaven: 1
#  Moonberg: 1
#  East Williamfurt: 1
#  Fieldsburgh: 1
#  Kirkton: 1
#  Delacruzport: 1
#  East Shawnstad: 1
#  Lake Stephaniemouth: 1
#  Port Kyleville: 1
#  Pittsside: 1
#  Port Kent: 1
#  New Clintonmouth: 1
#  Lake Leahburgh: 1
#  Gonzalesborough: 1
#  New Tammyland: 1
#  Kristahaven: 1
#  Port Joshuaville: 1
#  Weisston: 1
#  South Ericstad: 1
#  Salasland: 1
#  Rhodesmouth: 1
#  Port Gregoryshire: 1
#  Ricardoport: 1
#  Lake Ravenberg: 1
#  Holderburgh: 1
#  Bartonshire: 1
#  South Travischester: 1
#  North Rachelview: 1
#  Riceborough: 1
#  North Amandaton: 1
#  Mendezport: 1
#  West Stacyland: 1
#  New Traceybury: 1
#  North Ebonyborough: 1
#  Berryberg: 1
#  Lovefurt: 1
#  Port Katrinashire: 1
#  West Traciville: 1
#  Port Stephaniefort: 1
#  Garrettfort: 1
#  Gailville: 1
#  South Trevorshire: 1
#  Barrerashire: 1
#  South Leslieborough: 1
#  North Ashleeside: 1
#  South Sheilaport: 1
#  Gilmorestad: 1
#  Goodton: 1
#  Darrylfort: 1
#  Veleztown: 1
#  East Kellie: 1
#  Berryfurt: 1
#  Bridgetstad: 1
#  Wallfurt: 1
#  Port Lauratown: 1
#  New Carmenville: 1
#  Gonzalesville: 1
#  Lake Shirleyfort: 1
#  North Jonathanshire: 1
#  Townsendside: 1
#  West Nicholasside: 1
#  New Annaton: 1
#  Hopkinsport: 1
#  Lake Stanleyfort: 1
#  Chenborough: 1
#  New Albertborough: 1
#  Lake Kevinton: 1
#  Aprilstad: 1
#  South Joshuabury: 1
#  Krausehaven: 1
#  Hinesport: 1
#  Sarastad: 1
#  Debbieland: 1
#  West Ashleyfort: 1
#  Masseyport: 1
#  South Brandonhaven: 1
#  Edwardshaven: 1
#  Lake Mikaylahaven: 1
#  Dickersonville: 1
#  Baldwinshire: 1
#  North Christopherfurt: 1
#  South Vincentberg: 1
#  North Juanport: 1
#  Jeanborough: 1
#  Walterschester: 1
#  Mendozachester: 1
#  North Lisachester: 1
#  Lake Deborahburgh: 1
#  Sierrafort: 1
#  Lake Darin: 1
#  Lake Calebside: 1
#  East Ivan: 1
#  New Marvin: 1
#  New Lindseyville: 1
#  Waltersfurt: 1
#  Port Traci: 1
#  West Juanland: 1
#  Shermanbury: 1
#  Adrienneview: 1
#  West Arielburgh: 1
#  Harmonside: 1
#  North Meaganberg: 1
#  North Devonberg: 1
#  Woodardfurt: 1
#  Lake Ronaldburgh: 1
#  Villaland: 1
#  Reidport: 1
#  Lake Amandaborough: 1
#  Lake Marcusville: 1
#  East Lonniechester: 1
#  Strongshire: 1
#  Port Robinmouth: 1
#  South Adamside: 1
#  Lake Lynnland: 1
#  Port Tami: 1
#  Ortegabury: 1
#  Robertsonberg: 1
#  Port Cassie: 1
#  East Codyhaven: 1
#  New Lancemouth: 1
#  Mollyburgh: 1
#  East Dianeside: 1
#  Bennettchester: 1
#  East Rickyfort: 1
#  Gillfurt: 1
#  Deckerbury: 1
#  Underwoodburgh: 1
#  Chapmantown: 1
#  New Scottton: 1
#  Haynesfort: 1
#  Joannebury: 1
#  Maysside: 1
#  Wileystad: 1
#  West Pamelashire: 1
#  West Amyborough: 1
#  East Johntown: 1
#  Marissahaven: 1
#  Huangland: 1
#  Bassport: 1
#  Bradyborough: 1
#  Jensenland: 1
#  Loweshire: 1
#  Cummingsport: 1
#  Shortside: 1
#  South Christianburgh: 1
#  Port Bethmouth: 1
#  Glennport: 1
#  Boothside: 1
#  Brandonbury: 1
#  Lake Ryanview: 1
#  New Sharonhaven: 1
#  Lake Brandiport: 1
#  Horneshire: 1
#  Port Sandybury: 1
#  North Aimee: 1
#  West Charlesbury: 1
#  Escobarmouth: 1
#  North Heidimouth: 1
#  East Rachelside: 1
#  North Robertofurt: 1
#  Barryfort: 1
#  Eduardoborough: 1
#  Harringtonmouth: 1
#  Lake Coreyborough: 1
#  South Rickytown: 1
#  West Bradleyborough: 1
#  Clineborough: 1
#  New Kennethmouth: 1
#  West Jeffreychester: 1
#  West Joshuaport: 1
#  East Lindashire: 1
#  South Victoriafort: 1
#  Port Deborahstad: 1
#  Lake Tanyachester: 1
#  Chunghaven: 1
#  Blairshire: 1
#  Comptonfurt: 1
#  Tatehaven: 1
#  South Jacobtown: 1
#  West Travisshire: 1
#  Mariahfurt: 1
#  Soniaton: 1
#  South Pamelatown: 1
#  North Kimberlyview: 1
#  South Marvinside: 1
#  North Ernest: 2
#  Lake Robertabury: 1
#  South Lindaport: 1
#  West Laurentown: 1
#  Lake Heatherburgh: 1
#  North Ericaborough: 1
#  Port Haileyborough: 1
#  Port Henryland: 1
#  North Jeremyton: 1
#  Barberside: 1
#  Morsemouth: 1
#  Jakebury: 1
#  South Ellenburgh: 1
#  New Kathymouth: 1
#  New Theresaberg: 1
#  Anneland: 1
#  North Timothychester: 1
#  New Carlabury: 1
#  Armstrongtown: 1
#  East Jeffville: 1
#  Bridgetland: 1
#  East Scotthaven: 1
#  Travisville: 1
#  East Nancyshire: 1
#  West Reneemouth: 1
#  Annaberg: 1
#  Selenaside: 1
#  South Haleyshire: 1
#  South Austinside: 1
#  New Jasminefurt: 1
#  Barberhaven: 1
#  Swansonborough: 1
#  Port Janeland: 1
#  South Thomasburgh: 1
#  New Melvin: 1
#  Ernestchester: 1
#  New Donnaview: 1
#  East Victoriastad: 1
#  Lake Matthewberg: 1
#  New Denisetown: 1
#  West Edwardfort: 1
#  Lake Courtneyfurt: 1
#  East Tinaburgh: 1
#  Englishtown: 1
#  Rosarioport: 1
#  Lake Shellyview: 1
#  Port Latoyastad: 1
#  North Meganville: 1
#  Karlaside: 1
#  Mcdonaldville: 1
#  West Staceyfort: 1
#  Port Kyleside: 1
#  Port Lauraville: 1
#  South Brendanburgh: 1
#  Burchfort: 1
#  North Crystaltown: 1
#  New Kathleenfort: 1
#  Burnettbury: 1
#  East Robinstad: 1
#  Norrisland: 1
#  South Cathyland: 1
#  West Juanmouth: 1
#  New Garyhaven: 1
#  East Heidishire: 1
#  Costafort: 1
#  Gaineshaven: 1
#  North Gordon: 1
#  West Craigmouth: 1
#  New Shannonside: 1
#  South Paulaburgh: 1
#  East Gregoryhaven: 1
#  East Chadmouth: 1
#  West Wayneside: 1
#  Lake Keithtown: 1
#  West Brendaland: 1
#  North Ivanstad: 1
#  South Anthonyview: 1
#  Heathton: 1
#  Port Erikport: 1
#  Buckton: 1
#  Lake Heatherton: 1
#  North Amandaberg: 1
#  New Fernandohaven: 1
#  Port Heiditon: 1
#  Duranfurt: 1
#  Lake Anthonyview: 1
#  Port Josephport: 1
#  South Leebury: 1
#  Ianberg: 1
#  East Carlshire: 1
#  South Julieborough: 1
#  East Jeanettehaven: 1
#  Barberbury: 1
#  Port Loriton: 1
#  Mayerview: 1
#  Kentside: 1
#  Woodwardton: 1
#  West Janiceborough: 1
#  New Hollytown: 1
#  New Chloe: 1
#  East Bradview: 1
#  Fernandezbury: 1
#  Mauriceton: 1
#  South Waynestad: 1
#  North Cole: 1
#  North Bryanshire: 1
#  Port Annaside: 1
#  Brendanport: 1
#  New Brianfurt: 1
#  Villegasborough: 1
#  Tapiastad: 1
#  Kirkfurt: 1
#  East Edwin: 1
#  Port Kaitlynberg: 1
#  Haydentown: 1
#  East Samanthafurt: 1
#  South Jordanstad: 1
#  South Johnnyburgh: 1
#  South Dianefurt: 1
#  Bautistaview: 1
#  Lake Evanburgh: 1
#  West Barbaratown: 1
#  North Rickymouth: 1
#  Lake Yvetteberg: 1
#  South Douglasport: 1
#  New Norma: 1
#  South Marciaberg: 1
#  Greerville: 1
#  West Samanthachester: 1
#  East Danaland: 1
#  Carlsonhaven: 1
#  Janetfurt: 1
#  New Roseport: 1
#  West Matthewland: 1
#  West Elizabethhaven: 1
#  Lake Christianburgh: 1
#  Port Sergio: 1
#  Sallyborough: 1
#  North Frankport: 1
#  Victorton: 1
#  North Kathrynborough: 1
#  South Carlosfort: 1
#  Everettland: 1
#  Loweberg: 1
#  New Peterbury: 1
#  East Rachelborough: 1
#  South Sheilahaven: 1
#  South Carolburgh: 1
#  West Gregoryberg: 1
#  Victorport: 1
#  Lake Billyborough: 1
#  Lake Austinberg: 1
#  North Ronniestad: 1
#  West Amandaborough: 1
#  South Bill: 1
#  Lake Debrafurt: 1
#  East Kaylaton: 1
#  New Brianfort: 1
#  Marthamouth: 1
#  North Ashleyhaven: 1
#  South Ambermouth: 1
#  New Moniquefort: 1
#  New Judithborough: 1
#  Cliffordbury: 1
#  South Marie: 1
#  Lake Trevormouth: 1
#  East Brendashire: 1
#  West Samuelfurt: 1
#  Port Williamside: 1
#  Samanthaport: 1
#  New Frankfort: 1
#  Fuentesfurt: 1
#  Robertsbury: 1
#  Port Karifurt: 1
#  West Brendanland: 1
#  Lake Sherriport: 1
#  New Danaborough: 1
#  West Bobbyborough: 1
#  Port Garrett: 1
#  Mcdowellburgh: 1
#  Ponceberg: 1
#  Parksville: 1
#  South Dawntown: 1
#  Cochranside: 1
#  Friedmanville: 1
#  New Samuelhaven: 1
#  South Tamarahaven: 1
#  North Gabriellechester: 1
#  Port Courtneyborough: 1
#  Tashamouth: 1
#  Gordonville: 1
#  New Kurttown: 1
#  New Heathershire: 1
#  North Anachester: 1
#  Atkinsberg: 1
#  Mandyshire: 1
#  Stokesville: 1
#  West Jennyville: 1
#  South Rick: 1
#  West Vanessashire: 1
#  New Haleyhaven: 1
#  East Beckyberg: 1
#  Stricklandburgh: 1
#  East Saraview: 1
#  South Monicamouth: 1
#  Mcbridefort: 1
#  East Tristanport: 1
#  East Ashleyland: 1
#  New Jimmyfort: 1
#  Estradaberg: 1
#  Farmertown: 1
#  South Deborahhaven: 1
#  Callahanbury: 1
#  West Carriebury: 1
#  West Lindaport: 1
#  West Amandafurt: 1
#  Finleyview: 1
#  Lake Timshire: 1
#  Barreraview: 1
#  New Andreafurt: 1
#  Port Timothystad: 1
#  Jermainefurt: 1
#  West Laurachester: 1
#  West Phillipbury: 1
#  South Brentshire: 1
#  North Austinchester: 1
#  Bergerborough: 1
#  North Edgarberg: 1
#  East Benjaminfurt: 1
#  Port Robinfort: 1
#  New Claire: 1
#  South Gavinville: 1
#  Mcknightview: 1
#  West Chloemouth: 1
#  South Madisonville: 1
#  Bentleytown: 1
#  West Carlaton: 1
#  North Courtneyfort: 1
#  West Mirandafort: 1
#  Mirandaberg: 1
#  Lake Nicolebury: 1
#  Port Rhondaside: 1
#  East Bethanytown: 1
#  Lake Lawrencehaven: 1
#  Lake Amybury: 1
#  Lake Andreabury: 1
#  West Dariusmouth: 1
#  Navarroport: 1
#  Port Tamaramouth: 1
#  South Margaretstad: 1
#  East Briannaland: 1
#  Marcusport: 1
#  Penningtonview: 1
#  Beardstad: 1
#  East Jacquelineland: 1
#  Lake Lindashire: 1
#  New Larryberg: 1
#  Lake Shellyport: 1
#  East Alexanderburgh: 1
#  Mcguireville: 1
#  Port Karina: 1
#  South Joelburgh: 1
#  West Taylormouth: 1
#  Simschester: 1
#  East Shaneburgh: 1
#  South Adamville: 1
#  South Cindytown: 1
#  North Gregbury: 1
#  North Rhondaview: 1
#  West Juanburgh: 1
#  Lake Crystalton: 1
#  Port Laurieville: 1
#  West Andresbury: 1
# ------------------------------
# CustomerGender:
#  Mode = Male
#  Unique Count = 3
#  Proportions:
#  Female: 33.05%
#  Other: 33.34%
#  Male: 33.60%
#  Frequency Counts:
#  Female: 33053
#  Other: 33343
#  Male: 33604
# ------------------------------
# CustomerIncomeGroup:
#  Mode = Medium
#  Unique Count = 3
#  Proportions:
#  Medium: 33.43%
#  High: 33.24%
#  Low: 33.33%
#  Frequency Counts:
#  Medium: 33428
#  High: 33244
#  Low: 33328
# ------------------------------
#
# Task 3 Runtime: 0.7832 seconds
